# %%
import json
import psycopg2
from dateutil import parser as dateparser

# %%
# ---------------------------------------------------------
# DATABASE CONNECTION
# ---------------------------------------------------------
conn = psycopg2.connect(
    host="localhost",
    database="mates",
    user="postgres",
    password="1"
)
conn.autocommit = True
cur = conn.cursor()

# %%
def get_or_create_source(source_url):
    cur.execute("""
        INSERT INTO sources (source_url, source_name)
        VALUES (%s, %s)
        ON CONFLICT (source_url) DO UPDATE SET source_name = EXCLUDED.source_name
        RETURNING source_id;
    """, (source_url, source_url))
    return cur.fetchone()[0]

# %%
def get_or_create_category(category_name):
    if not category_name:
        return None

    cur.execute("""
        INSERT INTO categories (category_name)
        VALUES (%s)
        ON CONFLICT (category_name) DO UPDATE SET category_name = EXCLUDED.category_name
        RETURNING category_id;
    """, (category_name,))
    return cur.fetchone()[0]

# %%
def get_or_create_tag(tag_name):
    cur.execute("""
        INSERT INTO tags (tag_name)
        VALUES (%s)
        ON CONFLICT (tag_name) DO UPDATE SET tag_name = EXCLUDED.tag_name
        RETURNING tag_id;
    """, (tag_name,))
    return cur.fetchone()[0]

# %%
def insert_article(article_data, source_id, category_id):
    publication_date = dateparser.parse(article_data["publication_date"]).date()
    scrape_date = dateparser.parse(article_data["scrape_date"])

    cur.execute("""
        INSERT INTO articles (
            url, source_id, category_id,
            publication_date, scrape_date,
            title, content,
            word_count, sentence_count, character_count,
            category_confidence
        )
        VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
        ON CONFLICT (url) DO UPDATE SET
            title = EXCLUDED.title,
            content = EXCLUDED.content,
            word_count = EXCLUDED.word_count,
            sentence_count = EXCLUDED.sentence_count,
            character_count = EXCLUDED.character_count,
            category_id = EXCLUDED.category_id,
            category_confidence = EXCLUDED.category_confidence,
            updated_at = CURRENT_TIMESTAMP
        RETURNING article_id;
    """, (
        article_data["url"],
        source_id,
        category_id,
        publication_date,
        scrape_date,
        article_data["title"],
        article_data["content"],
        article_data.get("word_count", 0),
        article_data.get("sentence_count", 0),
        article_data.get("character_count", 0),
        article_data.get("category_confidence", 0.0)
    ))

    return cur.fetchone()[0]

# %%
def insert_article_tags(article_id, tags):
    for tag_name in tags:
        tag_id = get_or_create_tag(tag_name)
        cur.execute("""
            INSERT INTO article_tags (article_id, tag_id)
            VALUES (%s, %s)
            ON CONFLICT (article_id, tag_id) DO NOTHING;
        """, (article_id, tag_id))

# %%
# ---------------------------------------------------------
# PROCESS A SINGLE ARTICLE (CORRECT FLOW)
# ---------------------------------------------------------
def process_article(article):
    print(f"→ Processing: {article['title'][:50]}")

    # 1. Insert / get source
    source_id = get_or_create_source(article["source"])

    # 2. Insert / get category
    category_id = get_or_create_category(article.get("primary_category"))

    # 3. Insert article
    article_id = insert_article(article, source_id, category_id)

    # 4. Insert tags
    tags = article.get("tags", [])
    insert_article_tags(article_id, tags)

    print(f"Article inserted with ID {article_id}")

# %%
# ---------------------------------------------------------
# MAIN ETL FUNCTION
# ---------------------------------------------------------
def run_etl(json_path):
    print("Loading JSON...")
    with open(json_path, "r", encoding="utf-8") as f:
        data = json.load(f)

    print(f"Found {len(data)} articles.")

    for article in data:
        try:
            process_article(article)
        except Exception as e:
            print("Error:", e)

    print("ETL Completed Successfully!")

# %%
if __name__ == "__main__":
    run_etl(r"D:\Menghour\MATES\data\datasets\raw\all_articles_cleaned.json")
# Out:
# Loading JSON...
# Found 7856 articles.
# → Processing: ចំនួននៃការវាយប្រហារ ទៅលើពលរដ្ឋរុស្ស៊ី នៅក្នុងប្រទេ
# Article inserted with ID 1
# → Processing: មន្រ្តីជាន់ខ្ពស់ក្រសួងទេសចរណ៍ ស្នើឱ្យស្ថាប័នពាក់ព័
# Article inserted with ID 2
# → Processing: លោក ម៉ឹង យូឡេង ប្រធានមន្ទីរសាធារណការ និងដឹកជញ្ជូនខ
# Article inserted with ID 3
# → Processing: កូរ៉េខាងជើង សាកល្បងយានក្រោមទឹក គ្មានមនុស្សបើកបំពាក
# Article inserted with ID 4
# → Processing: គេហទំព័រយោធាអាមេរិក ៖ វៀតណាមជាប់ជាប្រទេស ដែលយោធាមា
# Article inserted with ID 5
# → Processing: បើកពិធីសម្ពោធពិព័រណ៍ ទំនិញគុណភាព ខ្ពស់អន្តរជាតិ ឆ្
# Article inserted with ID 6
# → Processing: មន្រ្តីនាយកដ្ឋាន ដឹកជញ្ជូនរបស់វៀតណាម ដាក់បន្ទុកទៅល
# Article inserted with ID 7
# → Processing: ខ្មែរ ប៊ែវើរីជីស លើកកម្ពស់សកម្មភាពការលេងកីឡាដើម្បី
# Article inserted with ID 8
# → Processing: យន្តហោះ អ៊ីស្រាអែល វាយប្រហារ ទីតាំងបាញ់រ៉ុកកែត នៅល
# Article inserted with ID 9
# → Processing: នាយចឺម ឆាតញ៉ែសង្សារគេ ត្រូវគេលបវាយឡើង បែកក្បាល
# Article inserted with ID 10
# → Processing: ៖ ខ្លួននឹងជួសជុល បញ្ហាផ្នែកទន់ បន្ទាប់អតិថិជនម៉ូដែ
# Article inserted with ID 11
# → Processing: តុលាការយោធាមីយ៉ាន់ម៉ា កាត់ទោសលោកស្រី អ៊ុងសាន ស៊ូជី
# Article inserted with ID 12
# → Processing: អ៊ីស្រាអែល រាយការណ៍ជូនលោក អំពីដំណោះស្រាយរបស់ខ្លួន
# Article inserted with ID 13
# → Processing: បទវិភាគ ៖ មិត្តភាពរវាងចិន និងអាហ្វ្រិក អាចពុះពារឧប
# Article inserted with ID 14
# → Processing: របស់រុស្ស៊ីថា ចារកម្មអ៊ុយក្រែន និងអង់គ្លេស ព្យាយាម
# Article inserted with ID 15
# → Processing: បទវិភាគ ៖ កិច្ចសហប្រតិបត្តិការ ផ្តល់ផលប្រយោជន៍ ដល់
# Article inserted with ID 16
# → Processing: ព័ត៌មានជាតិសំខាន់ៗប្រចាំថ្ងៃ
# Article inserted with ID 17
# → Processing: ចិន សំណូមពរឲ្យអាមេរិកបញ្ឈប់ ការបន្ទោសនានា ជុំវិញបញ
# Article inserted with ID 18
# → Processing: លោកត្រាំ ចង់បង្ហាញពី ស្នាដៃស្វែងរកសន្តិភាពរបស់ខ្លួ
# Article inserted with ID 19
# → Processing:
# Article inserted with ID 20
# → Processing: កម្ពុជា ឥណ្ឌូនេស៊ី ព្រមព្រៀងចុះ លើវិស័យសុខាភិបាល ន
# Article inserted with ID 21
# → Processing: ធនាគារ អេស ប៊ី អាយ លី ហួរ សាខា៧មករា បានបើកសាខាថ្មី
# Article inserted with ID 22
# → Processing: កូវីដ១៩ បំផ្លាញសេដ្ឋកិច្ចកម្ពុជា ជិត៣ពាន់លានដុល្លា
# Article inserted with ID 23
# → Processing: សម្ដេចតេជោ តបវិញថា មរតក សម្ដេច មិនត្រឹមវ៉ាក់សាំងប៉
# Article inserted with ID 24
# → Processing: អាល្លឺម៉ង់ ធ្វើសមយុទ្ធយោធាទ្រង់ទ្រាយធំ នៅជិតព្រំដែ
# Article inserted with ID 25
# → Processing: កសិកម្ម៖ តើពលរដ្ឋខ្ជិល មន្ត្រីខ្ជិល ឬរដ្ឋខ្វះយន្តក
# Article inserted with ID 26
# → Processing: សម្ដេចតេជោ ហ៊ុន សែន ផ្តល់ម៉ាសក្រណាត់ចំនួន ១លាន ដល់
# Article inserted with ID 27
# → Processing: កងកម្លាំងយោធារុស្សី ជោគជ័យបើកការវាយប្រហារ លើទីតាំង
# Article inserted with ID 28
# → Processing: អម្រឹត ចុះអនុស្សរណៈ យោគយល់ ជាមួយ និង ក្នុងការលើកកម
# Article inserted with ID 29
# → Processing: ធុងសំរាមចំនួន ៩៣៩ធុង ត្រូវបានក្រសួងបរិស្ថាន បន្តយក
# Article inserted with ID 30
# → Processing: ថៃ ហាមពលរដ្ឋឥណ្ឌា និងជនបរទេសដែលមកពីឥណ្ឌា មិនឱ្យចូល
# Article inserted with ID 31
# → Processing: ឡាវ រកឃើញអ្នកផ្ទុកវីរុសកូរ៉ូណា ជាលើកដំបូង ចំនួន០២ក
# Article inserted with ID 32
# → Processing: អ៊ីរ៉ង់ ជំរុញឲ្យសហរដ្ឋអាមេរិក ដកចេញគោល នយោបាយប្រឆា
# Article inserted with ID 33
# → Processing: អាជ្ញាធររាជធានីភ្នំពេញ បានបន្ដបិទ ចរាចរណ៍បណ្តោះអាស
# Article inserted with ID 34
# → Processing: សម្តេចធិបតី៖ កម្ពុជា ទទួលយកប្រព័ន្ធច្បាប់ខ្មែរ តាម
# Article inserted with ID 35
# → Processing: កូរ៉េខាងត្បូង អនុម័តប្រើថ្នាំវ៉ាក់សំាង កូវីដ១៩
# Article inserted with ID 36
# → Processing: ក្រសួងការពារជាតិចិន ៖ ទំនាក់ទំនងយោធា ចិន កម្ពុជា ដ
# Article inserted with ID 37
# → Processing: រដ្ឋបាលរាជធានីភ្នំពេញ សម្រេចផ្អាករៀបចំ សង្ក្រាន្តវ
# Article inserted with ID 38
# → Processing: សម្ដេចតេជោ សំណូមពរ បក្សនយោបាយ និងអង្គការសង្គមស៊ីវិ
# Article inserted with ID 39
# → Processing: អាល្លឺម៉ង់ ផ្លាស់ប្តូរផែនការ ដោយលែងសាងសង់រោងចក្រជួ
# Article inserted with ID 40
# → Processing: ៖ សេតវិមាន បញ្ជាក់ថា កូរ៉េខាងជើង ផ្គត់ផ្គង់គ្រាប់ក
# Article inserted with ID 41
# → Processing: ៖ កូរ៉េខាងជើង ថ្កោលទោសយ៉ាងដាច់អហង្ការ ទៅលើការធ្វើស
# Article inserted with ID 42
# → Processing:
# Article inserted with ID 43
# → Processing: មន្រ្តីទីភ្នាក់ងារអវកាស៖ យានអវកាស របស់ប្រទេសជប៉ុន
# Article inserted with ID 44
# → Processing: អ្នកមានមុន មិនគួរលុបលាងមុខ ញឹកញាប់ពេកទេ
# Article inserted with ID 45
# → Processing: សម្ដេច ស ខេង ៖ ការបង្រៀននៅសាលាមត្តេយ្យឲ្យបានល្អ ជា
# Article inserted with ID 46
# → Processing: បទវិភាគ ៖ បុគ្គលឈ្មោះវីលៀម ឡៃកាន់តែព្រហើន ក៏កាន់តែ
# Article inserted with ID 47
# → Processing: ជប៉ុន ប្ដេជ្ញាជំរុញកិច្ចសហប្រតិបត្តិការបន្ថែមទៀត រ
# Article inserted with ID 48
# → Processing: សម្ដេចតេជោ ជំរុញអាជ្ញាធរបម្រេី សេវាសាធារណៈ ជូនពលរដ
# Article inserted with ID 49
# → Processing: សមត្ថកិច្ចនគរបាលខេត្តស្ទឹងត្រែង បានបង្ក្រាបករណីប្ល
# Article inserted with ID 50
# → Processing: ជនជាតិអាល្លឺម៉ង់ ភាគច្រើន ប្រឆាំងនឹងការបញ្ជូន អាវុ
# Article inserted with ID 51
# → Processing: ព្រឹត្តិការណ៍ សំខាន់ៗប្រចាំថ្ងៃ
# Article inserted with ID 52
# → Processing: បទវិភាគ៖លីទុយអានីដែលអួតអាងថា ខ្លួនជា អ្នកគាំពារប្រ
# Article inserted with ID 53
# → Processing: សម្តេចធិបតី ផ្តាំទៅសហជីព កុំយកកម្មករ ទៅធ្វើការងារ
# Article inserted with ID 54
# → Processing: បទវិភាគ ៖ សេដ្ឋកិច្ចចិន មានការចាប់ផ្តើម ដ៏ល្អប្រសើ
# Article inserted with ID 55
# → Processing: លោក និយាយពីកម្ពុជា៖ ថ្នាក់ដឹកនាំថ្មីនឹងនាំមកនូវវឌ្
# Article inserted with ID 56
# → Processing: រុស្ស៊ី សងសឹកអ៊ុយក្រែនដោយវាយប្រហារ លើអាកាសយានដ្ឋាន
# Article inserted with ID 57
# → Processing: មន្ត្រីសេត វិមានគូសបញ្ជាក់ អំពីពេលវេលា កាន់តែខិតជិ
# Article inserted with ID 58
# → Processing: កម្ពុជា ស្នើ ជួយពិនិត្យឡើងវិញ នូវគម្រោងសិក្សា រថភ្
# Article inserted with ID 59
# → Processing: ចិន ប្រកាសជំហប្រឆាំងនឹង ការបញ្ចេញទឹក វិទ្យុសកម្មហ្
# Article inserted with ID 60
# → Processing: ឯកឧត្តម ឃួង ស្រេង គោរពជូនពរ សម្ដេចតេជោ និងសម្ដេចកិ
# Article inserted with ID 61
# → Processing: សារព័ត៌មានផ្សាយថា នាយករដ្ឋមន្ត្រីជប៉ុន លោក នឹងប្រក
# Article inserted with ID 62
# → Processing: គិតត្រឹមព្រឹកថ្ងៃទី១៦ តុលា នៅកម្ពុជា មានអ្នកស្លាប់
# Article inserted with ID 63
# → Processing: ហុងគ្រី ថ្កោលទោស ថវិកាអឺរ៉ុបឆ្នាំ ២០២៨ ២០៣៤ ថាជា ថ
# Article inserted with ID 64
# → Processing: ទូលព្រះបង្គំខ្ញុំបាទ នេត្រ ភក្ត្រា ថ្វាយសារលិខិតថ្
# Article inserted with ID 65
# → Processing: ប្រេសិតពិសេសប្រធានអាស៊ាន ដឹកនាំគណៈប្រតិភូអញ្ជើញ ទៅ
# Article inserted with ID 66
# → Processing: សម្ដេច ស ខេង ដឹកនាំកិច្ចប្រជុំស្ដីពីលទ្ធផល កិច្ចប្
# Article inserted with ID 67
# → Processing: នាយករដ្ឋមន្រ្តីកម្ពុជា អបអរសាទរ ស៊ន សៀវម៉ី ដណ្តើមម
# Article inserted with ID 68
# → Processing: ជំនន់ទឹកភ្លៀងនៅខេត្តបន្ទាយមានជ័យ ប៉ះពាល់ប្រជាជន ជា
# Article inserted with ID 69
# → Processing: ព័ត៌មានជាតិនិងអន្តរជាតិ សំខាន់ៗប្រចាំថ្ងៃ
# Article inserted with ID 70
# → Processing: អភិបាលខេត្តកំពង់ចាម និងលោកស្រី ឧបត្ថម្ភថវិកាប្រាំព
# Article inserted with ID 71
# → Processing: ខេត្តកំពង់ស្ពឺ បន្តរកឃើញ អ្នកឆ្លងជំងឺកូវីដ ១៩ ចំនួ
# Article inserted with ID 72
# → Processing: សម្ដេច ស ខេង អំពាវនាវឲ្យអភិបាលខេត្តជាប់ព្រំដែនវៀតណ
# Article inserted with ID 73
# → Processing: លោកឧកញ៉ាទៀ វិចិត្រ ឧបត្ថម្ភ ១០០០ដុល្លារ ឲ្យលោកនូ ស
# Article inserted with ID 74
# → Processing: ប្រធានគណៈកម្មាការអឺរ៉ុបថា ការអនុញ្ញាតឱ្យបាញ់ទម្លាក
# Article inserted with ID 75
# → Processing: បច្ចុប្បន្ន ម្តាយជនជាតិអាមេរិក មើលទូរទស្សន៍ច្រើនជា
# Article inserted with ID 76
# → Processing: គណបក្សប្រជាជនកម្ពុជា នឹងបើកមហាសន្និបាត វិសាមញ្ញទូទ
# Article inserted with ID 77
# → Processing: អ្នកកាសែតជើងចាស់ ខាងតាមដានភូមិសាស្ត្រនយោបាយ លោក សយ
# Article inserted with ID 78
# → Processing: លោក ត្រាំ ចុះហត្ថលេខាលើសេចក្តីប្រកាស បន្ធូរបន្ថយសម
# Article inserted with ID 79
# → Processing: ការដឹកជញ្ជូនទំនិញ ចេញពីកម្ពុជា មានកំណើនក្នុងរង្វង់
# Article inserted with ID 80
# → Processing: នាយករដ្ឋមន្រ្តី សម្រេចបិទការធ្វើដំណើរឆ្លងកាត់ ពីខេ
# Article inserted with ID 81
# → Processing: ព័ត៌មានអន្តរជាតិសំខាន់ប្រចាំសប្ដាហ៍
# Article inserted with ID 82
# → Processing: លោក ជា ធីរិទ្ធ៖ សម រង្ស៊ី តែងតែយកចំណេញ ពីព្រឹត្តិក
# Article inserted with ID 83
# → Processing: អភិបាលខេត្តកំពង់ចាម ណែនាំថ្នាក់ដឹកនាំស្ថាប័ន អង្គភ
# Article inserted with ID 84
# → Processing: សហរដ្ឋអាមេរិកអះអាងថា នឹងធ្វើពហិកាកិច្ចប្រជុំកំពូល
# Article inserted with ID 85
# → Processing: ឡាវ សម្រេចបិទ ទីក្រុងវៀងច័ន្ទ ទាំងមូល បន្ទាប់ពីរកឃ
# Article inserted with ID 86
# → Processing: កានណាន ជាចំណុចប្រសព្វ នៃចរាចរណ៍ពាណិជ្ជកម្មសូត្រ កា
# Article inserted with ID 87
# → Processing: អភិបាលខេត្តកំពង់ចាម នាំអំណោយសម្ដេចតេជោ ចែកជូនប្រជា
# Article inserted with ID 88
# → Processing: ប្រេស៊ីល និងអារ៉ាប៊ីសាអូឌីត ចុះកុងត្រាវិនិយោគរួមគ្
# Article inserted with ID 89
# → Processing: អភិបាលខេត្តកំពង់ចាម ៖ ប្រទេសមានសុខសន្តិភាព និងកំពុ
# Article inserted with ID 90
# → Processing: កត្តាសន្តិភាព និងការគោរពព្រះពុទ្ធសាសនា ជាកត្តាជំរុ
# Article inserted with ID 91
# → Processing: មនុស្ស ១៣នាក់ ត្រូវបានសម្លាប់ ដោយសារការវាយប្រហារ ដ
# Article inserted with ID 92
# → Processing: ក្រសួងសុខាភិបាល៖ ការរុករកស្រាវជ្រាវ នៃការចម្លងជំងឺ
# Article inserted with ID 93
# → Processing: ក្រសួងបរិស្ថាន បន្តផ្តល់ធុងសំរាមចំនួន ១៥៤ធុង ទៅតាម
# Article inserted with ID 94
# → Processing: សម្ដេច ស ខេង អញ្ជើញផ្សព្វផ្សាយការងារ គ្រប់គ្រងហត្ថ
# Article inserted with ID 95
# → Processing: បទវិភាគ ៖ តើអ្នកណា ជាជើងចាស់ ក្នុងការបង្កការគំរាម
# Article inserted with ID 96
# → Processing: ជប៉ុន ផ្ដល់គ្រឿង ឥស្សរិយយស ជូនលោក ឈាង វុន សម្រាប់ន
# Article inserted with ID 97
# → Processing: រុស្ស៊ី ព្រមាន អ៊ីស្រាអែល កុំឱ្យ វាយប្រហារ ទីតាំង
# Article inserted with ID 98
# → Processing: កូរ៉េខាងត្បូង រន្ធត់ចិត្ត និងសោកស្ដាយ ក្រោយមនុស្សស
# Article inserted with ID 99
# → Processing: សម្ដេចតេជោ ហ៊ុន សែន អញ្ជើញចូលរួមបេីក កិច្ចប្រជុំកំ
# Article inserted with ID 100
# → Processing: រដ្ឋមន្ត្រីការពារជាតិ មីយ៉ាន់ម៉ា នឹងមានវត្តមាន ក្ន
# Article inserted with ID 101
# → Processing: ព័ត៌មានអន្តរជាតិសំខាន់ៗប្រចាំថ្ងៃ
# Article inserted with ID 102
# → Processing: បទអត្ថាធិប្បាយ ៖ ក្នុងពេល៣ឆ្នាំ បង្ហាញពីប្រសិទ្ធភា
# Article inserted with ID 103
# → Processing: សម្តេចធិបតី៖ អ្នកខ្លះពូកែរិះគន់រាជរដ្ឋាភិបាល បានក្
# Article inserted with ID 104
# → Processing: សមាជិកសភាឥណ្ឌាម្នាក់ ដែលជាចៅប្រុស របស់អតីតនាយករដ្ឋ
# Article inserted with ID 105
# → Processing: សម្តេចធិបតី អញ្ជើញសម្ពោធ អាកាសយានដ្ឋានអន្តរជាតិសៀម
# Article inserted with ID 106
# → Processing: ក្រុមហ៊ុនអាកាសចរណ៍អាមេរិក បានចាប់ផ្តើមលុបចោល ជើងហោ
# Article inserted with ID 107
# → Processing: សម្ដេច ស ខេង ដាក់ប្រើប្រាស់ផែនការសកម្មភាព ទប់ស្កាត
# Article inserted with ID 108
# → Processing: ឆ្នាំ២០២០ កម្ពុជាសម្រេចបាន ទំហំពាណិជ្ជកម្មជាង ៣៥ពា
# Article inserted with ID 109
# → Processing: ជប៉ុន ព្រួយបារម្ភ យ៉ាង ខ្លាំង ចំពោះ ពន្ធ អាករ ទៅវិ
# Article inserted with ID 110
# → Processing: សម្តេចតេជោ និងសម្តេចកិត្តិព្រឹទ្ធបណ្ឌិត ចាក់វ៉ាក់ស
# Article inserted with ID 111
# → Processing: សម្ដេចតេជោ ហ៊ុន សែន អញ្ជើញទទួលស្វាគមន៍ នាយករដ្ឋមន្
# Article inserted with ID 112
# → Processing: ប្រទេសចិន នៅតែជាដៃគូពាណិជ្ជកម្មដ៏ធំបំផុត របស់អាស៊ា
# Article inserted with ID 113
# → Processing: រុស្ស៊ី រកឃើញករណី ឆ្លងជំងឺកូវីដ១៩ថ្មី ជាង១៦០ ០០០នា
# Article inserted with ID 114
# → Processing: មហាសេដ្ឋីអាមេរិក ថា លោកនឹងត្រឡប់មកបន្តការងារវិញ ២៤
# Article inserted with ID 115
# → Processing: សម្ដេចតេជោ លុបចោល កម្មវិធីទាំងអស់ និងកម្មវិធីជួប រ
# Article inserted with ID 116
# → Processing: សម្ដេចតេជោ ព្រមានកំចាត់ចោល រាល់បក្សនយោបាយណា ពាក់ព័
# Article inserted with ID 117
# → Processing: ក្រសួងធនធានទឹក បង្ហាញព្រឹត្តិបត្រព័ត៌មាន និងព្យាករ
# Article inserted with ID 118
# → Processing: ប ស ស សម្រេចដាក់សាកល្បង របបសន្តិសុខសង្គម ផ្នែកថែទា
# Article inserted with ID 119
# → Processing: សម្ដេច ស ខេង អំពាវនាវ ឲ្យពលរដ្ឋបើកបរ គោរពច្បាប់ខណៈ
# Article inserted with ID 120
# → Processing: មេចុងភៅខ្មែរដ៏ល្បីល្បាញម្នាក់ ចែករំលែកបទពិសោធន៍ធ្វ
# Article inserted with ID 121
# → Processing: បទវិភាគ៖ តើប្រជាជនអាចធ្វើជាម្ចាស់ផ្ទះប្រទេសជាតិ ឬអ
# Article inserted with ID 122
# → Processing: ការស្ទង់មតិបង្ហាញថា ក្រុមការងារតូក្យូ បំបែកគ្នា ទៅ
# Article inserted with ID 123
# → Processing: ក្រសួងសុខាភិបាល អំពាវនាវឲ្យពលរដ្ឋប្រុងប្រយ័ត្ន ចំព
# Article inserted with ID 124
# → Processing: វៀតណាម មានអ្នកឆ្លងជំងឺកូវីដ ១៩ថ្មីចំនួន១០នាក់ នាំឲ
# Article inserted with ID 125
# → Processing: អភិបាលរងខេត្តកំពង់ចាម ណែនាំឲ្យមន្ត្រីយកចិត្តទុកដាក
# Article inserted with ID 126
# → Processing: ៖ កម្ពុជា ជួបកោះម៉ារីអាណា ខាងជើងល្ងាចនេះ ក្រោយចាញ់
# Article inserted with ID 127
# → Processing: ព័ត៌មានជាតិនិងអន្តរជាតិ សំខាន់ៗប្រចាំថ្ងៃ
# Article inserted with ID 128
# → Processing: ចំនួនអ្នកស្លាប់ដោយទឹកជំនន់នៅប្រទេសមីយ៉ាន់ម៉ា កើនឡើ
# Article inserted with ID 129
# → Processing: រដ្ឋមន្ដ្រីសុខាភិបាល៖ ចំនួនអ្នកស្ម័គ្រចិត្ត ចាក់វ៉
# Article inserted with ID 130
# → Processing: ទទួលទានម្នាស់ អាចជួយប្រឆាំង រោគផ្តាសាយបាន
# Article inserted with ID 131
# → Processing: ក្រុមហ៊ុនបច្ចេកវិទ្យាយក្ស សម្រេចផ្លាស់ប្តូរផលិតកម្
# Article inserted with ID 132
# → Processing: សម្តេចតេជោ នឹងធ្វើជាប្រធានកិច្ចប្រជុំកំពូល មហាអនុត
# Article inserted with ID 133
# → Processing: វៀតណាម រកឃើញអ្នកឆ្លង វីរុសកូរ៉ូណាថ្មីជាង ៨ ០០០នាក់
# Article inserted with ID 134
# → Processing: សម្ដេចតេជោ ហ៊ុន សែន ប្រាប់រដ្ឋមន្ត្រីយុត្តិធម៌ ធ្វ
# Article inserted with ID 135
# → Processing: រដ្ឋមន្ត្រីក្រសួងការងារ កោតសរសើរ បេឡាជាតិសន្ដិសុខស
# Article inserted with ID 136
# → Processing: ,
# Article inserted with ID 137
# → Processing: ប្រធានសភានេប៉ាល់ ជឿជាក់ថា តួនាទីនិងសមិទ្ធផលដែល សម្
# Article inserted with ID 138
# → Processing: បទវិភាគ ៖ កិច្ចសន្ទនា និងការចរចា គឺជាផ្លូវចេញតែមួយ
# Article inserted with ID 139
# → Processing: បទវិភាគ ៖ តើការងារការពារ សិទ្ធិមនុស្ស របស់ប្រទេសចិ
# Article inserted with ID 140
# → Processing: សហគ្រិនវ័យក្មេងបង្ហាញសមត្ថភាព និងគំនិតអាជីវកម្មនៅល
# Article inserted with ID 141
# → Processing: ព្រឹកស្អែក សម្តេចតេជោ ហ៊ុន សែន នឹងអញ្ជើញទទួលវ៉ាក់ស
# Article inserted with ID 142
# → Processing: សម្តេចតេជោ ៖ អ្នកចាក់វ៉ាក់សាំងទី ៥លាននាក់ បានទៅបុរ
# Article inserted with ID 143
# → Processing: ប្រធានាធិបតីកូរ៉េខាងត្បូង ស្នើសុំជំនួយវៀតណាម ក្នុង
# Article inserted with ID 144
# → Processing: មេដឹកនាំក្រុមអាវក្រហមថៃ ពិចារណាបង្កើនការប្រមូលផ្តុ
# Article inserted with ID 145
# → Processing: លួចរថយន្តម៉ាក នៅព្រះសីហនុ សមត្ថកិច្ចតាមចាប់មកវិញ
# Article inserted with ID 146
# → Processing: ករណីឆ្លងជំងឺកូវីដ ១៩ ប្រចាំថ្ងៃនៅវៀតណាម កើនឡើងដល់ជ
# Article inserted with ID 147
# → Processing: ដាក់ដំណើរការ ដំណោះស្រាយការតភ្ជាប់ថ្មីសម្រាប់ជីវិតស
# Article inserted with ID 148
# → Processing: អតីតកីឡាករ បាល់ទាត់ក្លឹប ត្រូវតុលាការ កាត់ទោស ឱ្យជ
# Article inserted with ID 149
# → Processing: ស្អែកនេះ អគ្គិសនីស្វាយរៀង នឹងផ្អាកការផ្គត់ផ្គង់អគ្
# Article inserted with ID 150
# → Processing: រុស្ស៊ី និងអ៊ុយក្រែន ធ្វើកិច្ចចរចាស្របគ្នា ដែលសម្រ
# Article inserted with ID 151
# → Processing: ម៉ាឡេស៊ី ធានាបានវ៉ាក់សាំងលើស ចំនួនពលរដ្ឋដល់ទៅ ១០ភា
# Article inserted with ID 152
# → Processing: ទីបំផុត ស្មាតហ្វូនពេញនិយម អ្នកឯកទេសស៊ែលហ្វី សាហាវ
# Article inserted with ID 153
# → Processing: កម្មវិធីទំនាក់ទំនង បណ្ដាញសង្គមរបស់ ក្រុមហ៊ុនហ្វេស
# Article inserted with ID 154
# → Processing: កម្ពុជា បញ្ចៀសបានអំពើភេរវកម្ម និងបង្ក្រាបទាន់ពេលវេ
# Article inserted with ID 155
# → Processing: ប្រព័ន្ធសន្ដិសុខសង្គម គឺជាប្រព័ន្ធមួយដ៏ល្អប្រសើរ ដ
# Article inserted with ID 156
# → Processing: ចេញការអំពាវនាវដល់ពិភពលោក ឲ្យពន្យាពេលចាក់ដូសជំរុញ ស
# Article inserted with ID 157
# → Processing: សម្តេចធិបតី នឹងបញ្ជូនអ្នកពូកែបាញ់ បោះអាណាធិបតេយ្យ
# Article inserted with ID 158
# → Processing: បទវិភាគ ៖ ទទួលស្វាគមន៍ ភ្ញៀវមកពីគ្រប់ទិសទី ស្វែងរក
# Article inserted with ID 159
# → Processing: អនុប្រធានាធិបតីអាមេរិក មិនទាន់បញ្ជាក់ថាតើការសាកល្ប
# Article inserted with ID 160
# → Processing: គ្រោះថ្នាក់រញ្ជួយដី ៦,៦រ៉ិចទ័រវាយ ប្រហារកោះមីនដាណា
# Article inserted with ID 161
# → Processing: ២ថ្ងៃ នៃការចាប់ផ្ដើមបុណ្យទន្លេ ទទួលបានភ្ញៀវទេសចរ ជ
# Article inserted with ID 162
# → Processing: អាល្លឺម៉ង់ ផ្តល់ជំនួយជាង ២លានដុល្លារដល់កម្ពុជា សម្
# Article inserted with ID 163
# → Processing: ឥណ្ឌា ហាមមិនឱ្យយកគ្រឿងបង្គុំ យន្តហោះគ្មានមនុស្សបើក
# Article inserted with ID 164
# → Processing: លោក ហ៊ុន ម៉ានី អញ្ជើញចូលរួមការប្រកួត ប្រដាល់គុនខ្ម
# Article inserted with ID 165
# → Processing: វៀតណាម ទទួលបានភ្ញៀវអន្តរជាតិ ៧,៨ លាននាក់ក្នុងរយៈពេ
# Article inserted with ID 166
# → Processing: ក្រោយជាសះស្បើយ ពីជំងឺកូវីដ១៩ សម្ដេចតេជោ ហ៊ុន សែន ម
# Article inserted with ID 167
# → Processing: កម្ពុជា ជាបេះដូងអាស៊ាន អាចប្រើជាមជ្ឈមណ្ឌល ឧស្សាហកម
# Article inserted with ID 168
# → Processing: សម្តេចធិបតី៖ ថ្ងៃទី២៩ធ្នូ គឺជាបង្គោលចរប្រវត្តិសាស្
# Article inserted with ID 169
# → Processing: ព័ត៌មានជាតិ និង អន្តរតជាតិសំខាន់ៗប្រចាំថ្ងៃ
# Article inserted with ID 170
# → Processing: ជប៉ុន ប្រឆាំងនឹងសមយុទ្ធយោធា របស់កូរ៉េខាងត្បូង ក្បែ
# Article inserted with ID 171
# → Processing: នាយករដ្ឋមន្ត្រីជប៉ុន ទំនងជានឹងមិនចូលរួម ក្នុងកិច្ច
# Article inserted with ID 172
# → Processing: ការចុះឈ្មោះចូលរៀន នៅថ្នាក់ក្រោយឧត្ដម នៃសាកលវិទ្យាល
# Article inserted with ID 173
# → Processing: លោក ថោង ខុន ៖ គណៈកម្មាធិការអន្តរជាតិ ប្រគល់មេដាយមរ
# Article inserted with ID 174
# → Processing: មេដាយមាសកម្ពុជា កើនឡើង៨១ហើយ ក្នុងចំណោមមេដាយសរុប២៨០
# Article inserted with ID 175
# → Processing: វៀតណាម ចាត់ទុកជប៉ុន ជាដៃសេដ្ឋកិច្ចកំពូលរបស់ខ្លួន
# Article inserted with ID 176
# → Processing: ថៃ ប្រកាស ពីអ្នកស្លាប់ ដោយសារជំងឺកូវីដ១៩ រហូតដល់ ៥
# Article inserted with ID 177
# → Processing: សាទរកម្ពុជាចាក់វ៉ាក់សាំងកូវីដ ក្នុងល្បឿនលឿន ដែលអាច
# Article inserted with ID 178
# → Processing: សប្បុរសជន បន្តនាំអំណោយផ្ដល់ជូន ប្រធានគណៈកម្មការ ចូ
# Article inserted with ID 179
# → Processing: សម្ដេចតេជោ ហ៊ុន សែន បញ្ជាឲ្យដកហូតដីព្រៃ ដែលជនខិលខូ
# Article inserted with ID 180
# → Processing: ជប៉ុន ព្រមានពីវិបត្តិជុំវិញបញ្ហាតៃវ៉ាន់ ជាហានិភ័យក
# Article inserted with ID 181
# → Processing: បទវិភាគ ៖ មហាសន្និបាត នៃសភាទាំងពីរ របស់ចិន នាំមកនូ
# Article inserted with ID 182
# → Processing: ការនាំចេញរបស់ថៃ ធ្លាក់ចុះ ១៤,៦ភាគរយ ក្នុងខែធ្នូ ឆ្
# Article inserted with ID 183
# → Processing: ឯកឧត្តម យឿន យឿត ផ្ញើសារលិខិតគោរពជូនពរ សម្តេចកិត្តិ
# Article inserted with ID 184
# → Processing: ព័ត៌មានជាតិ និង អន្តរជាតិសំខាន់ៗប្រចាំថ្ងៃ
# Article inserted with ID 185
# → Processing: អាមេរិក នៅតែស្រពិចស្រពិល ជុំវិញការវិលត្រឡប់របស់អ៊ី
# Article inserted with ID 186
# → Processing: ជាលើកទី២ខ្មែរប៊ែវើរីជីសប្រកាសឧបត្ថម្ភ១០ម៉ឺនដុល្លារ
# Article inserted with ID 187
# → Processing: លោក ត្រាំ បញ្ជាក់ថា មេដឹកនាំក្រុមរដ្ឋឥស្លាម ជ្រុលន
# Article inserted with ID 188
# → Processing: មេដឹកនាំ កំពូល កូរ៉េខាងជើង ចុះត្រួតពិនិត្យដោយផ្ទាល
# Article inserted with ID 189
# → Processing: កូវីដ ៖ រកឃើញឆ្លងថ្មីតាម ១៥១នាក់ ជា៣៦៦នាក់ និងស្លា
# Article inserted with ID 190
# → Processing: វិនិយោគិន២រូប បោះទុនរួមគ្នាលើគំរោងសាងសង់ ផ្ទះវីឡាល
# Article inserted with ID 191
# → Processing: ត្រឹមតែ១ថ្ងៃ ស្រ្តីសម្រាលកូន ជិត ១០០០នាក់ មកទទួលសេ
# Article inserted with ID 192
# → Processing: សម្តេចតេជោ៖ យើងកំពុងពិនិត្យលទ្ធភាព ចាក់វ៉ាក់សាំងកូ
# Article inserted with ID 193
# → Processing: អ្នកឆ្លងជំងឺកូវីដ១៩ថ្មី រកឃើញអ្នកឆ្លងថ្មី ២១៩នាក់ទ
# Article inserted with ID 194
# → Processing: យើងទាំងអស់គ្នា ប្រាកដជា ធ្លាប់មានពេលមួយ ដែលសួរថា ត
# Article inserted with ID 195
# → Processing: អាមេរិក គូសបន្ទាត់ក្រហមជាមួយអ៊ីរ៉ង់ ជុំវិញការចរចាន
# Article inserted with ID 196
# → Processing: កូរ៉េខាងជើង បាញ់ មីស៊ីល ផ្លោង រយៈ ចម្ងាយ ឆ្ងាយ ចូល
# Article inserted with ID 197
# → Processing: ជប៉ុន គ្រោងនឹងប្រកាស ដាក់រដ្ឋស្ថិតក្នុងគ្រាអាសន្ន
# Article inserted with ID 198
# → Processing: ព័ត៌មានសំខាន់ៗប្រចាំថ្ងៃ
# Article inserted with ID 199
# → Processing: ឯកឧត្តម កែវ រតនៈ អបអរសាទរ និងគោរពជូនពរ សម្តេចតេជោ
# Article inserted with ID 200
# → Processing: អ្នកទស្សនា កុំប៉ះវត្ថុទាំងឡាយណា នៅពហុកីឡដ្ឋានរតកតេ
# Article inserted with ID 201
# → Processing: ក្រសួងឧស្សាហកម្ម ដាក់ឲ្យប្រើប្រាស់សញ្ញា ផលិតផលកម្ព
# Article inserted with ID 202
# → Processing: បាញ់ និងឃាត់ខ្លួនស្ត្រីវ័យក្មេងម្នាក់ ព្យាយាមបើកឡា
# Article inserted with ID 203
# → Processing: សម្ដេចតេជោ ៖ ក្រុងអរិយក្សត្រ នឹងមិនកាត់ចូលរាជធានីភ
# Article inserted with ID 204
# → Processing: បទវិភាគ ៖ ប្តូរពីការផ្តោតសំខាន់ ទៅលើបរិមាណ ទៅជាការ
# Article inserted with ID 205
# → Processing: ទូលព្រះបង្គំខ្ញុំបាទ ឃួង ស្រេង, ទូលព្រះបង្គំខ្ញុំប
# Article inserted with ID 206
# → Processing: អេស្តូនីជឿជាក់ថា រុស្ស៊ីអាចនឹងវាយប្រហារ ទៅលើណាតូក្
# Article inserted with ID 207
# → Processing: ប្រតិភូក្រសួងអភិវឌ្ឍន៍ជនបទ អញ្ជើញដាក់កម្រងផ្កាគោរព
# Article inserted with ID 208
# → Processing: សមាជិក ជាតារាកូរ៉េដំបូងគេលេចមុខក្នុងស្ពតពាណិជ្ចកម្
# Article inserted with ID 209
# → Processing: សហរដ្ឋអាមេរិក ចាប់ផ្តើមបង្កើនទីតាំង ដាក់ពង្រាយមីស៊
# Article inserted with ID 210
# → Processing: អ៊ុយក្រែន ស្វាគមន៍ កិច្ចពិភាក្សាគ្នា រវាងលោក បៃដិន
# Article inserted with ID 211
# → Processing: វៀតណាម អំពាវនាវ ឱ្យអ្នកជំនួញបរិច្ចាគប្រាក់ ដើម្បីទ
# Article inserted with ID 212
# → Processing: មន្ត្រីជាន់ខ្ពស់ របបយោធាមីយ៉ាន់ម៉ា ចូលរួមកិច្ចប្រជ
# Article inserted with ID 213
# → Processing: កិច្ចសហប្រតិបត្តិការអាល្លឺម៉ង់ បន្ដកិច្ចសហការរៀបចំ
# Article inserted with ID 214
# → Processing: ជនជាតិវៀតណាម ៥៩នាក់ ត្រូវបានបណ្តេញចេញពីកម្ពុជា តាម
# Article inserted with ID 215
# → Processing: រដ្ឋមន្រ្តីបរិស្ថាន ៖ រដ្ឋបាលថ្នាក់ក្រោមជាតិ បានចូ
# Article inserted with ID 216
# → Processing: ជប៉ុន បិទបញ្ចប់ភាព អាសន្ន នៃជំងឺកូវីដ ១៩ នៅទីក្រុង
# Article inserted with ID 217
# → Processing: កងទ័ពអ៊ីស្រាអែល ប្រមូលផ្តុំគ្នា នៅព្រំដែនតំបន់ហ្គា
# Article inserted with ID 218
# → Processing: សាខាកាកបាទក្រហម ខេត្តកំពង់ចាម ប្រគល់ផ្ទះមនុស្សធម៌ច
# Article inserted with ID 219
# → Processing: ការដាច់ប្រព័ន្ធ ទូទាំងពិភពលោក បានបង្ខំឱ្យលុបចោលការ
# Article inserted with ID 220
# → Processing: ព័ត៌មានជាតិសំខាន់ៗប្រចាំថ្ងៃ
# Article inserted with ID 221
# → Processing: ថៃ មានអ្នកស្លាប់ដោយសារ វីរុសកូវីដ១៩ ម្នាក់ទៀត សរុប
# Article inserted with ID 222
# → Processing: សភា អ៊ីស្រាអែល អនុម័ត ថវិកា ដែល បាន ធ្វើ វិសោធនកម្
# Article inserted with ID 223
# → Processing: សំណុំរឿងបោកប្រាស់លុយ ៤៤ពាន់លានដុល្លារនៅវៀតណាម រដ្ឋ
# Article inserted with ID 224
# → Processing: ស្ថានទូតសាធារណរដ្ឋកូរ៉េ ប្រចាំកម្ពុជា៖ ការប្រកួតជម
# Article inserted with ID 225
# → Processing: នាយករដ្ឋមន្រ្តីថៃ បញ្ឈប់ការធ្វើទស្សនកិច្ច នៅក្រៅប្
# Article inserted with ID 226
# → Processing: អ៊ីរ៉ង់ ជំរុញឱ្យប្រធាន រក្សាភាពមិនលំអៀងរបស់ទីភ្នាក
# Article inserted with ID 227
# → Processing: លោក លើកឡើងថា អតីតប្រធានាធិបតីអាមេរិក គឺជាអ្នកទទួលខ
# Article inserted with ID 228
# → Processing: មេអាវុធហត្ថខេត្តកំពង់ស្ពឺ ជម្រុញឱ្យមន្ត្រីជំនាញបង្
# Article inserted with ID 229
# → Processing: សហគ្រិនថ្មីថ្មោង ត្រូវយល់ដឹងអ្វីខ្លះពីផ្នែកច្បាប់
# Article inserted with ID 230
# → Processing: អ្នកនាំពាក្យក្រសួងការបរទេសរុស្ស៊ីថា ប្រទេសអាល្លឺម៉
# Article inserted with ID 231
# → Processing: សេចក្តីព្រាងអនុក្រឹត្យ ស្តីពី ការបង្កើតក្រុមប្រឹក្
# Article inserted with ID 232
# → Processing: ស្រាបៀរកម្ពុជា អញ្ជើញអ្នកស្នេហាកីឡា ប្រដាល់ ទស្សនា
# Article inserted with ID 233
# → Processing: ការទទួលទានកាហ្វេ មិនអាចសម្រកទម្ងន់បានទេ
# Article inserted with ID 234
# → Processing: សម្ដេចតេជោ ប្រកាសថា គណបក្សប្រជាជនកម្ពុជា ជានិមិត្ត
# Article inserted with ID 235
# → Processing: ពីធីចែកវិញ្ញាបនបត្រ ជូនដល់និស្សិត ដែលបញ្ចប់វគ្គសិក
# Article inserted with ID 236
# → Processing: អ្នកប្រដាល់គុនខ្មែរខ្លាចាស់ ផាន់ គ្រាន់ ផ្តួលអ្នកប
# Article inserted with ID 237
# → Processing: ទាញយក ឥឡូវនេះ លោកអ្នក នឹងទទួលបាន ព័ត៌មានថ្មីៗ នៅក្
# Article inserted with ID 238
# → Processing: សម្តេចតេជោ ដឹកនាំគណៈប្រតិភូ មកដល់កម្ពុជាវិញហើយ
# Article inserted with ID 239
# → Processing: ៖ អាមេរិក បញ្ជាក់ជំហរ មិនជ្រៀតជ្រែក ចូលកិច្ចការផ្ទ
# Article inserted with ID 240
# → Processing: រាជរដ្ឋាភិបាល លើកទឹកចិត្តពលរដ្ឋ មានលទ្ធភាពទៅចាក់វ៉
# Article inserted with ID 241
# → Processing: ប្រធាន ហិរញ្ញវត្ថុ ជប៉ុន និង អាមេរិក យល់ ព្រម ពិគ្
# Article inserted with ID 242
# → Processing: ចូលរួមអបអរ ព្រះរាជពិធីបុណ្យអុំទូក ជាមួយណាហ្គាវើលដ៍
# Article inserted with ID 243
# → Processing: នាយឧត្តមសេនីយ៍ ហ៊ុន ម៉ាណែត ប្រាប់ទូតអង់គ្លេស ចង់ឃើ
# Article inserted with ID 244
# → Processing: ,
# Article inserted with ID 245
# → Processing: សម្ដេច ស ខេង ណែនាំមន្ដ្រីគណបក្សប្រជាជន ត្រូវខិតខំរ
# Article inserted with ID 246
# → Processing: អនុប្រធានាធិបតីអាមេរិកលោក ចង់ប្រើប្រាស់លុយសមាជិកណា
# Article inserted with ID 247
# → Processing: ព្រឹទ្ធសភា អនុម័តលុបចោល កិច្ចព្រមព្រៀង ដោយចាត់ទុកជ
# Article inserted with ID 248
# → Processing: រដ្ឋមន្ត្រីក្រសួងព័ត៌មាន និងថ្នាក់ដឹកនាំខេត្តកំពង់
# Article inserted with ID 249
# → Processing: ក្រុមហ៊ុន សច្ចៈប្រផឹធី ជម្រុញការ ទិញ លក់ អចលនទ្រព្
# Article inserted with ID 250
# → Processing: អតីតអធិកាបតីអាល្លឺម៉ង់ ៖ មេដឹកនាំអ៊ុយក្រែន ជាច្រើន
# Article inserted with ID 251
# → Processing: ប្រធានសភាអ៊ីរ៉ង់ ៖ សំណើកិច្ចព្រមព្រៀង នុយក្លេអ៊ែរ
# Article inserted with ID 252
# → Processing: សែលកាត បានចាប់ផ្តើម កម្មវិធីបរិច្ចាគ ថវិកា ដើម្បីជ
# Article inserted with ID 253
# → Processing: កូរ៉េខាងត្បូង ស្នើឲ្យមានការ និយាយគ្នាជាមួយកូរ៉េខាង
# Article inserted with ID 254
# → Processing: ទីភ្នាក់ងារឱសថអឺរ៉ុប ណែនាំឲ្យប្រថ្នាំ ២ប្រភេទ ដើម្
# Article inserted with ID 255
# → Processing: សម្តេចតេជោ កំពុងថ្លែងសារពិសេស ក្នុងឱកាសបើកយុទ្ធនាក
# Article inserted with ID 256
# → Processing: បទវិភាគ ៖ កម្លាំងផលិតកម្ម គុណភាពថ្មី នឹងជំរុញការអភ
# Article inserted with ID 257
# → Processing: រដ្ឋមន្ត្រី ហេង សួរ អញ្ជើញចូលរួម ក្នុងពិធីអបអរសាទរ
# Article inserted with ID 258
# → Processing: ព័ត៌មានសំខាន់ៗប្រចាំថ្ងៃ
# Article inserted with ID 259
# → Processing: ក្រសួងសុខាភិបាលអាមេរិក នឹងដាក់សម្ពាធទៅលើប្រេស៊ីល ដ
# Article inserted with ID 260
# → Processing: កម្ពុជា និងអូស្ត្រាលី ពង្រីកកិច្ចសហប្រតិបត្តិការផ្
# Article inserted with ID 261
# → Processing: សមាគមវារីវប្បករ៖ លក់ត្រីចេញមិនដល់២០ ធ្វើឲ្យអ្នកចិញ
# Article inserted with ID 262
# → Processing: លោក ប្រកាសផ្តល់ជំនួយ ២ពាន់លានអឺរ៉ូបន្ថែមទៀត ទៅឲ្យអ
# Article inserted with ID 263
# → Processing: ព័ត៌មានសំខាន់ៗប្រចាំថ្ងៃ
# Article inserted with ID 264
# → Processing: អាស៊ីអាគ្នេយ៍ ក្នុងយុទ្ធសាស្ត្រ របស់ពួកប្រទេសមហាអំ
# Article inserted with ID 265
# → Processing: ឡានក្រុង ៣៥០គ្រឿង ត្រៀមដឹកជញ្ជូនពលរដ្ឋ ដោយឥតគិតថ្ល
# Article inserted with ID 266
# → Processing: ៖ កូរ៉េខាងជើង រកឃើញគ្រាប់បែក និងអាវុធផលិតដោយសហរដ្ឋ
# Article inserted with ID 267
# → Processing: អ៊ីរ៉ង់ បង្កើនសមត្ថភាពផលិតអ៊ុយរ៉ាញ៉ូម រហូតដល់ ១៦,៥
# Article inserted with ID 268
# → Processing: ជប៉ុន និងណាតូ ព្រមព្រៀងគ្នាបង្កើនកិច្ច សហប្រតិបត្ត
# Article inserted with ID 269
# → Processing: កាតា អះអាងថា កិច្ចខិតខំប្រឹងប្រែងសម្របសម្រួល រវាងក
# Article inserted with ID 270
# → Processing: លោក កុសល ច័ន្ទស័ក្តិវិទូ ជំនះបង្កើតក្រុមហ៊ុន ដោយខ្
# Article inserted with ID 271
# → Processing: លឿនឡើង កម្មវិធីមហាប្រូម៉ូសិន ថែមជូនដ៏អស្ចារ្យ ក្នុ
# Article inserted with ID 272
# → Processing: មេដឹកនាំរុស្សី និងបារាំង ពិភាក្សាគ្នាលើបញ្ហាជនអន្ត
# Article inserted with ID 273
# → Processing: ផ្លែស្វាយ ស្រស់ដំបូងរបស់កម្ពុជា បានចូលដល់ទីផ្សារតំ
# Article inserted with ID 274
# → Processing: រាជរដ្ឋាភិបាល ផ្តល់អាទិភាពខ្ពស់លើការងារគ្រប់គ្រងគ្
# Article inserted with ID 275
# → Processing: អតីតនាយករដ្ឋមន្ត្រីថៃ លោក បា្រយុទ្ធ ចាន់អូចា ត្រូវ
# Article inserted with ID 276
# → Processing: លោក នូវ តាល់ ចុះផ្សព្វផ្សាយច្បាប់ចរាចរណ៍ផ្លូវគោក ន
# Article inserted with ID 277
# → Processing: កម្ពុជា និង រដ្ឋលិចតិនស្តាញ នៅអឺរ៉ុប ឯកភាពបន្តកិច្
# Article inserted with ID 278
# → Processing: ប៉ាឡេស្ទីនបញ្ជាក់ថា កម្លាំងអន្តរជាតិនៅតំបន់ហ្គាហ្ស
# Article inserted with ID 279
# → Processing: សេចក្តីប្រកាសព័ត៌មានរួម ក្រុមហ៊ុន និង ក្រុមហ៊ុន នៃ
# Article inserted with ID 280
# → Processing: ខេត្តប៉ៃលិន ជាគោលដៅទី៦ នៃសិក្ខាសាលា តាមបណ្ដាខេត្ត
# Article inserted with ID 281
# → Processing: កូរ៉េខាងជើង ប្រកាសផ្តាច់ ទំនាក់ទំនងការទូត ជាមួយម៉ា
# Article inserted with ID 282
# → Processing: នាយកប្រតិបត្ដិ មានទំនុកចិត្ដថា វ៉ាក់សាំង នឹងមានប្រ
# Article inserted with ID 283
# → Processing: អធិការនគរបាល ក្រុងកំពង់ឆ្នាំង បានដឹកនាំចុះឃាត់ខ្លួ
# Article inserted with ID 284
# → Processing: ក្រុមអ្នក នយោបាយអាមេរិក យល់ឃើញថា ជាកម្មវិធីមួយគំរា
# Article inserted with ID 285
# → Processing: ចិន ជំរុញឲ្យអាមេរិក បញ្ឈប់ជាបន្ទាន់ នូវរាល់ទម្រង់
# Article inserted with ID 286
# → Processing: សម្ដេចតេជោ ហ៊ុន សែន ពោលពាក្យយ៉ាងផ្អែមល្ហែម ទៅកាន់ស
# Article inserted with ID 287
# → Processing: ឥណ្ឌា ប្រើប្រព័ន្ធអាវុធទំនើប វាយប្រហារប៉ាគីស្ថាន៖
# Article inserted with ID 288
# → Processing: កូវីដ ៖ គ្មានឆ្លង ជា និងស្លាប់ថ្មីទៀតទេ
# Article inserted with ID 289
# → Processing: ប្រេសិតអាមេរិក ទទួលបន្ទុកកិច្ចការកូរ៉េខាងជើង នឹងធ្
# Article inserted with ID 290
# → Processing: អធិកាបតីអាល្លឺម៉ង់ អះអាងថា ការប៉ះពាល់សេដ្ឋកិច្ចរបស
# Article inserted with ID 291
# → Processing: សម្ដេចតេជោ អញ្ជើញជាអធិបតីភាពម្ពោធ ដាក់ឲ្យប្រើប្រាស
# Article inserted with ID 292
# → Processing: យ៉ាងហោចណាស់ សិស្សសាលាចំនួន ១១នាក់ បាត់បង់ជីវិតនៅក្
# Article inserted with ID 293
# → Processing: មិត្តហ្វូន ផ្តល់សេវាពិនិត្យសុខភាពដោយឥតគិតថ្លៃ ដល់ប
# Article inserted with ID 294
# → Processing: ឧត្តម សេនីយ៍ ឯក ម៉ឹង កុម្ភៈ សូមគោរពអបអរសាទរ និងគោរ
# Article inserted with ID 295
# → Processing: គ្រាន់តែ គ្រឿងអលង្ការ របស់ នៅលើដៃម្ខាង មានតម្លៃជាង
# Article inserted with ID 296
# → Processing: សម្ដេច ស ខេង ណែនាំឱ្យ ពង្រឹង កិច្ច ការពារ សុវត្ថិភ
# Article inserted with ID 297
# → Processing: អឺរ៉ុប ដាក់បម្រាមធ្វើដំណើរ ឡើងវិញលើប្រទេសជប៉ុន ចំព
# Article inserted with ID 298
# → Processing: ភ្ញៀវទេសចរ មកដើរលេងកំសាន្តនៅខេត្តបាត់ដំបងជាង ១២ម៉ឺ
# Article inserted with ID 299
# → Processing: តុលាការកំពូល របស់ប្រទេសថៃ សម្រេចរំលាយគណបក្សប្រឆាំង
# Article inserted with ID 300
# → Processing: ម៉ាឡេស៊ី រកឃើញអ្នកឆ្លងជំងឺកូវីដ ១៩ កើនឡើងលើស៣លាននា
# Article inserted with ID 301
# → Processing: របបអាហារ សម្រាប់អ្នកបញ្ហាជំងឹបេះដូង គួរយល់ដឹង
# Article inserted with ID 302
# → Processing: ជប៉ុន អះអាងថា សកម្មភាពរបស់ចិន នៅជិតប្រជុំកោះសេនកាគ
# Article inserted with ID 303
# → Processing: សម្ដេចតេជោ ដង្ហែសម្ដេចព្រះមហាក្សត្រី ក្នុងព្រះរាជព
# Article inserted with ID 304
# → Processing: សម្លឹងមើលវេទិកា សម្រាប់អាស៊ីទុកជាមុន៖ ពង្រឹងសេចក្ត
# Article inserted with ID 305
# → Processing: ក្រុមអត្តពលិកកីឡាការ៉ាតេកម្ពុជា ដណ្តើមមេដាយ ៧ គ្រឿ
# Article inserted with ID 306
# → Processing: នាយករដ្ឋមន្រ្តី បញ្ជាឱ្យចាត់វិធានការ បង្ក្រាបជាបន្
# Article inserted with ID 307
# → Processing: បទវិភាគ ៖ គោលនយោបាយថ្មី នៃមហាសន្និបាត នៃសភាទាំងពីរ
# Article inserted with ID 308
# → Processing: ជប៉ុន និងកូរ៉េខាងត្បូង សម្ដែងព្រួយបារម្ភយ៉ាងខ្លាំង
# Article inserted with ID 309
# → Processing: សម្ដេចតេជោ ប្តេជ្ញាថា នឹងទទួលខុសត្រូវ ខ្ពស់បំផុត ក
# Article inserted with ID 310
# → Processing: មីយ៉ាន់ម៉ា មានអ្នកឆ្លងជំងឺគ្រុនឈាមរហូតដល់ជាង៦ពាន់ន
# Article inserted with ID 311
# → Processing: នាយករដ្ឋមន្ត្រី មិនឱ្យប្រជាជនស្រែក អត់វ៉ាក់សាំងចាក
# Article inserted with ID 312
# → Processing: រុស្ស៊ី បញ្ជូនយន្ដហោះ ទម្លាក់គ្រាប់បែក យុទ្ធសាស្រ្
# Article inserted with ID 313
# → Processing: អតិផរណា ឬថ្លៃទំនិញនៅអាមេរិក កើនឡើងខ្ពស់បំផុត ក្នុង
# Article inserted with ID 314
# → Processing: លោក ម៉ឹង យូឡេង ផ្ញើសារលិខិតគោរពជូនពរ សម្ដេចតេជោ ហ៊
# Article inserted with ID 315
# → Processing: អ្នកស្រាវជ្រាវប្រវត្តិសាស្ត្រ ផ្តាំទៅលោក រ៉ុង ឈុន
# Article inserted with ID 316
# → Processing: ណាហ្គាវើលដ៍ បេះដូងសប្បុរស សហការជាមួយ នឹងរៀបចំទិវាគ
# Article inserted with ID 317
# → Processing: សមាគម រៀបចំផែនទី បង្ហាញផ្លូវ ដើម្បីឆ្ពោះទៅមុខ
# Article inserted with ID 318
# → Processing: តុលាការធម្មនុញ្ញាថៃ មានភស្តុតាងគ្រប់គ្រាន់ ក្នុងសំ
# Article inserted with ID 319
# → Processing: ព័ត៌មានអន្តរជាតិសំខាន់ៗប្រចាំថ្ងៃ
# Article inserted with ID 320
# → Processing: កូរ៉េខាងជើង បាញ់មីស៊ីលផ្លោងរយៈចម្ងាយមធ្យម ឆ្ពោះទៅក
# Article inserted with ID 321
# → Processing: កូរ៉េខាងជើង បើកកិច្ចប្រជុំកាកបាទក្រហម ស្របពេលមានកា
# Article inserted with ID 322
# → Processing: សម្ដេចតេជោ ៖ ប្រជារាស្រ្តទូទាំងប្រទេស សូមសម្តែង នូ
# Article inserted with ID 323
# → Processing: បទវិភាគ ៖ បន្ទាប់ពីបញ្ចប់សង្គ្រាម នៅអាហ្វហ្កានីស្ថ
# Article inserted with ID 324
# → Processing: អាមេរិក និងចិន កាត់បន្ថយពន្ធថ្មីភាគច្រើន បន្ទាប់ពី
# Article inserted with ID 325
# → Processing: អធិកាបតី អាល្លឺម៉ង់ អះអាងថា អ៊ឺរ៉ុបនឹងលែងត្រូវការហ
# Article inserted with ID 326
# → Processing: លោក កែវ រតនៈ បោះឆ្នោតនៅការិយាល័យ ០៣២២ ក្នុងស្រុកក្
# Article inserted with ID 327
# → Processing: សហគមន៍អន្តរជាតិ ត្រូវតែធ្វើសកម្មភាព ដើម្បីបញ្ឈប់ អ
# Article inserted with ID 328
# → Processing: អ៊ីស្រាអែល ដាក់ពង្រាយប្រព័ន្ធ ការពារមីស៊ីលពហុស្រទា
# Article inserted with ID 329
# → Processing: ភាពតានតឹងកើនឡើងខ្លាំង ខណៈនាវាចិន កំពុងធ្វើដំណើរចូល
# Article inserted with ID 330
# → Processing: សិល្បៈខ្មែរកូនខ្មែរអ្នកលើកស្ទួយខ្មែរ ប៊ែវើរីជីសប្រ
# Article inserted with ID 331
# → Processing: សម្ដេចតេជោ ព្រមទទួលធ្វើជា បេក្ខភាព សម្រាប់ពានរង្វា
# Article inserted with ID 332
# → Processing: ជប៉ុន និងអឺរ៉ុប ពិចារណាបង្កើន កិច្ចសហប្រតិបត្តិការ
# Article inserted with ID 333
# → Processing: ពិតជាមិនធម្មតាទេ ត្រឹម ២៤ម៉ោង កូរ៉េខាងត្បូង មានករណ
# Article inserted with ID 334
# → Processing: ក្នុងខែឧសភានេះ កម្ពុជាមានការងារ ប្រមាណជិត៥ម៉ឺនកន្ល
# Article inserted with ID 335
# → Processing: កូវីដ ៖ រកឃើញឆ្លងថ្មី១១២នាក់ ជា២៦៣នាក់ និងស្លាប់៨ន
# Article inserted with ID 336
# → Processing: អាមេរិក ផ្អាកការធ្វើពាណិជ្ជកម្ម ដោយមិនបង់ពន្ធ សម្រ
# Article inserted with ID 337
# → Processing: បទវិចារណកថា ទំនាក់ទំនងរវាង កូរ៉េខាងជើង និងរុស្ស៊ី៖
# Article inserted with ID 338
# → Processing: សម្ដេចតេជោ ព្រមានចាប់ខ្លួនជនទាំងឡាយណា បំពុលសង្គមទា
# Article inserted with ID 339
# → Processing: អ៊ីរ៉ង់ ៖ ពេលវេលា គឺមិនសមស្រប ទៅនឹងកិច្ចប្រជុំក្រៅ
# Article inserted with ID 340
# → Processing: ជប៉ុនអាចក្លាយ ជាអ្នកប្រកួតប្រជែងថ្មី ជាមួយចិន ក្រោ
# Article inserted with ID 341
# → Processing: អ៊ីរ៉ង់ ថ្កោលទោសការវាយប្រហារ របស់អ៊ីស្រាអែល លើទីក្
# Article inserted with ID 342
# → Processing: ប្រធានាធិបតី វៀតណាម ហៅទំនាក់ទំនង វៀតណាម អាមេរិក ថា
# Article inserted with ID 343
# → Processing: វីធីកម្ចាត់រង្វង់ភ្នែកខ្មៅ តាមបែបធម្មជាតិ
# Article inserted with ID 344
# → Processing: មន្ទីរអភិវឌ្ឍន៍ជនបទ ប្រគល់ភារកិច្ចជូនអាជ្ញាធរភូមិឃ
# Article inserted with ID 345
# → Processing: ប្រតិភូ ប ស ស ចូលរួមសិក្ខាសាលាអន្ដរជាតិ ស្តីពី ភាព
# Article inserted with ID 346
# → Processing: របាយការណ៍៖ ការធ្វើពាណិជ្ជកម្ម រវាងកូរ៉េខាងជើង និងអ
# Article inserted with ID 347
# → Processing: រដ្ឋមន្ត្រីការពារជាតិរុស្សី ព្រមានថា រាល់ការឈ្លានព
# Article inserted with ID 348
# → Processing: អភិបាលខេត្តកំពង់ចាម ៖ យើងត្រូវបន្តធ្វើការអភិវឌ្ឍន៍
# Article inserted with ID 349
# → Processing: អ្នកឧកញ៉ា ទៀ វិចិត្រ និងលោកជំទាវ ផ្ញើសារអបអរសាទរជូ
# Article inserted with ID 350
# → Processing: កីឡាការិនី កាំង មុយនីន ឈ្នះមេដាយមាស ខណៈឃឺន ប៊ុនពេជ
# Article inserted with ID 351
# → Processing: កម្ពុជា ប្តេជ្ញាសម្រេច គោលដៅកាត់បន្ថយ ការបំភាយឧស្ម
# Article inserted with ID 352
# → Processing: ក្រុមបាល់ទាត់ ព្រះខ័នរាជស្វាយរៀង គ្រងជើងឯក ពានរង្វ
# Article inserted with ID 353
# → Processing: ប្រធានាធិបតីរុស្ស៊ី លោក ពូទីន ពាក់ឈុតការពារមេរោគ អ
# Article inserted with ID 354
# → Processing: ឥណ្ឌា កំពុងស្វែងរកការកាត់ បន្ថយចំនួនអ្នកការទូត កាណ
# Article inserted with ID 355
# → Processing: ក្លិបអ្នកកាសែតកម្ពុជា និង រៀបចំវេទិកាសារព័ត៌មានលើក
# Article inserted with ID 356
# → Processing: សម្តេចតេជោ ៖ កីឡាករកម្ពុជាត្រូវដណ្តើមមេដាយមាស ឲ្យច
# Article inserted with ID 357
# → Processing: លំនៅឋាន បែបធម្មជាតិ រចនាបទ បែបខ្មែរ អឺរ៉ុប នឹងលេចរ
# Article inserted with ID 358
# → Processing: សិក្ខាសាលាស្ដីពី កម្ពុជា ចិន រួមជោគវាសនាប្រយុទ្ធប្
# Article inserted with ID 359
# → Processing: គោលនយោបាយ គាំទ្រអាមេរិក ដ៏លើសលប់ របស់លោក អាចក្លាយជ
# Article inserted with ID 360
# → Processing: អាល្លឺម៉ង់៖ រុស្ស៊ី ស្នើឲ្យដៃគូអឺរ៉ុប បន្ដការបង់ថ្
# Article inserted with ID 361
# → Processing: ឯកឧត្តម ឃួង ស្រេងសូមក្រាបបង្គំទូលថ្វាយព្រះពរ សម្តេ
# Article inserted with ID 362
# → Processing: សម្ដេចតេជោ ហ៊ុន សែន អញ្ជើញបំពេញទស្សនកិច្ច នៅប្រទេស
# Article inserted with ID 363
# → Processing: លោក ពូទីន ប្ដេជ្ញាវាយបកអ៊ុយក្រែនវិញ សម្រាប់ការ វាយ
# Article inserted with ID 364
# → Processing: ថៃ នឹងមិនគិតថ្លៃលើសេវាទិដ្ឋាការ ពីអ្នកទេសចរមកពី ៩៣
# Article inserted with ID 365
# → Processing: សមិទ្ធផលកូនខ្មែរ ថ្នាក់ដឹកនាំជាន់ខ្ពស់របស់ក្រុមហ៊ុ
# Article inserted with ID 366
# → Processing: រុស្ស៊ី ចាប់ផ្ដេីមដំណេីរ ការសាកល្បង នាវាមុជទឹកនុយក
# Article inserted with ID 367
# → Processing: លរដ្ឋរងផលប៉ះពាល់ដោយទឹកជំនន់ ៣១គ្រួសារ នៅស្រុកកងមាស
# Article inserted with ID 368
# → Processing: មកដល់ថ្ងៃ២២ កុម្ភៈ មានអ្នកទៅចាក់វ៉ាក់សាំងកូវីដ១៩ រ
# Article inserted with ID 369
# → Processing: ផ្ទុះដ៏កក្រើក នៅឯសាលារៀនមួយកន្លែង ក្នុងប្រទេសមីយ៉ា
# Article inserted with ID 370
# → Processing: អាល្លឺម៉ង់ ទិញរថក្រោះចាស់ៗ ជាច្រើនផ្គត់ផ្គង់ ឲ្យអ៊
# Article inserted with ID 371
# → Processing: រដ្ឋបាលខេត្តកំពង់ចាម និងរៀបចំប្រារព្ធពិធីប្រណាំងទូ
# Article inserted with ID 372
# → Processing: កាសែតគោលនយោបាយអឺរ៉ុប លើកឡើងថាសមាជិកណាតូត្រូវការពេល
# Article inserted with ID 373
# → Processing: ថ្នាក់ដឹកនាំខេត្តកំពង់ចាម ដឹកនាំមន្ត្រីក្រោមឱវាទ គ
# Article inserted with ID 374
# → Processing: លោក សា ឌីណា៖ ការបង្កើត ក្លិបកីឡាបាញ់ធ្នូភូមិន្ទកម្
# Article inserted with ID 375
# → Processing: កូវីដ ៖ ឆ្លងថ្មី១៦នាក់ ជា១៩នាក់ និងគ្មានស្លាប់
# Article inserted with ID 376
# → Processing: អង់គ្លេសថា យើង ត្រូវធ្វើគ្រប់យ៉ាង ដើម្បីបញ្ឈប់ម៉ាស
# Article inserted with ID 377
# → Processing: ជប៉ុន និងហ្វីលីពីន ព្រមព្រៀងគ្នា លើកិច្ចចរចាយុទ្ធស
# Article inserted with ID 378
# → Processing: ការិយាល័យកិច្ចការតៃវ៉ាន់នៃ ក្រុម ប្រឹក្សា កិច្ច កា
# Article inserted with ID 379
# → Processing: ជប៉ុនផ្ដល់ជំនួយឥតសំណង ២៧លានដុល្លារ សម្រាប់គម្រោងអភ
# Article inserted with ID 380
# → Processing: ខាន់ ចេសា យកឈ្នះដៃគូប្រកួតមកពីសិង្ហបុរី វៀតណាមនិងថ
# Article inserted with ID 381
# → Processing: ជិះម៉ូតូគេចពីគោ បែជាចូលទៅបុករថយន្ត ស្លាប់ពីរនាក់ប្
# Article inserted with ID 382
# → Processing: រុស្ស៊ី លូកដៃជួយបេឡារុស្ស ដែលកំពុងរងសម្ពាធ ពីលោកខា
# Article inserted with ID 383
# → Processing: កម្ពុជា ឈរលំដាប់លេខ២ ក្នុងអាស៊ាន ដែលចាក់វ៉ាក់សាំង
# Article inserted with ID 384
# → Processing: តាមស្ថិតិ ទើបដឹងថា អាចជាប់ឈ្មោះ ជាកីឡាករល្អបំផុត ប
# Article inserted with ID 385
# → Processing: លោក ពូទីន៖ រុស្ស៊ី គ្មានទីត្រូវដកថយ ជុំវិញបញ្ហាអ៊ុ
# Article inserted with ID 386
# → Processing: សម្ដេចតេជោ ៖ តាំងពីអនុវត្ត កម្មវិធីឧបត្ថម្ភសាច់ប្រ
# Article inserted with ID 387
# → Processing: លោក លី រតនរស្មី ត្រូវបានដកតំណែង ចេញពីទីប្រឹក្សា សម
# Article inserted with ID 388
# → Processing: អភិបាលខេត្តតាកែវ ណែនាំយុវជនអ្នកបង្កើតមាតិកា ត្រូវប
# Article inserted with ID 389
# → Processing: ២២ឆ្នាំ ថ្ងៃវាយប្រហារជាភេរវកម្ម មកលើអគារភ្លោះ នៅ ស
# Article inserted with ID 390
# → Processing: សម្តេចតេជោ ស្នើតុលាការពន្លឿន ដោះស្រាយសំណុំរឿងក្នុង
# Article inserted with ID 391
# → Processing: ព័ត៌មានជាតិ និង អន្តរជាតិសំខាន់ៗប្រចាំថ្ងៃ
# Article inserted with ID 392
# → Processing: ព័ត៌មានអន្តរជាតិសំខាន់ប្រចាំសប្ដាហ៍
# Article inserted with ID 393
# → Processing: កម្ពុជា បញ្ជូនមន្ត្រីជំនាញ ចូលរួមក្នុងបេសកកម្ម សង្
# Article inserted with ID 394
# → Processing: លោក គឺជាអ្នកដែលបានអនុញ្ញាតិ ឲ្យមានផែនការវាយប្រហារ
# Article inserted with ID 395
# → Processing: បិទចរាចរយាន យន្តគ្រប់ប្រភេទ ធ្វើដំណើរលើកំណាត់ផ្លូវ
# Article inserted with ID 396
# → Processing: ព័ត៌មានអន្តរជាតិសំខាន់ៗប្រចាំសប្ដាហ៍
# Article inserted with ID 397
# → Processing: បទវិភាគ៖ តួលេខដ៏ធ្ងន់ធ្ងរទាំងពីរ ៥០លាននាក់ និង ៨សែ
# Article inserted with ID 398
# → Processing: លោក នេត្រ ភក្ត្រា៖ សូមអំពាវនាវឲ្យក្រសួងស្ថាប័នរដ្ឋ
# Article inserted with ID 399
# → Processing: កូវីដ៖ ឆ្លងថ្មី៤៨៨នាក់ ជា៣០៥នាក់ និងស្លាប់៣នាក់
# Article inserted with ID 400
# → Processing: ព្រែកជីកហ្វូណនតេជោ ជាចំណាប់ខ្មាំង នៃឧបាយកលយុទ្ធសាស
# Article inserted with ID 401
# → Processing: អ៊ីស្រាអែល អះអាងថា ក្រុម ហាម៉ាស់ ច្រានចោល សំណើ កិច
# Article inserted with ID 402
# → Processing: អឺរ៉ុប ចង់ឲ្យចិន ជួយដល់កិច្ចខំប្រឹងប្រែង ដាក់ទណ្ឌក
# Article inserted with ID 403
# → Processing: វៀតណាម បញ្ជាក់ថា កម្ពុជា គឺជាមិត្តដ៏ពិសេស និងជាដៃគ
# Article inserted with ID 404
# → Processing: បទវិភាគ ៖ មតិអវិជ្ជមាន ដែលឃោសនាបំប៉ោងថា ទុនវិនិយោគ
# Article inserted with ID 405
# → Processing: រុស្ស៊ី ព្រមានតួកគីជុំវិញ ចំណងមិត្តភាពជាមួយអ៊ុយក្រ
# Article inserted with ID 406
# → Processing: សម្តេចធិបតី៖ ក្រុមប្រឆាំងស្រែកថាស្នេហាជាតិ តែបែរជា
# Article inserted with ID 407
# → Processing: អ៊ីរ៉ង់ អះអាងថា អាមេរិក ត្រូវតែទទួលខុសត្រូវ ចំពោះត
# Article inserted with ID 408
# → Processing: ជនជាតិវៀតណាម ៣៤នាក់ទៀត ត្រូវបានបណ្តេញចេញពីកម្ពុជា
# Article inserted with ID 409
# → Processing: ប្រជាជនអ៊ីស្រាអែល រាប់ពាន់នាក់ ធ្វើការតវ៉ាប្រឆាំង
# Article inserted with ID 410
# → Processing: អ៊ុយក្រែនអះអាងថា ខ្លួនបានវាយប្រហារ ធ្វើឱ្យខូចខាត ឬ
# Article inserted with ID 411
# → Processing: សម្ដេចតេជោ ហ៊ុន សែន អនុញ្ញាតឲ្យអគ្គនាយក សហព័ន្ធសន្
# Article inserted with ID 412
# → Processing: ព័ត៌មានជាតិសំខាន់ៗប្រចាំថ្ងៃ
# Article inserted with ID 413
# → Processing: អាល្លឺម៉ង់ ចេញការព្រមានទៅចិន ជុំវិញរបាយការណ៍សម្ងាត
# Article inserted with ID 414
# → Processing: ព័ត៌មានជាតិ និង អន្តរជាតិសំខាន់ៗប្រចាំថ្ងៃ
# Article inserted with ID 415
# → Processing: ធនាគារហ្វីលីព ប្រកាសបើក សា ខា ថ្មី តំណាងឲ្យ សា ខា
# Article inserted with ID 416
# → Processing: ការនាំចេញរបស់កូរ៉េខាងត្បូង កើនឡើងជាង ៤០ភាគរយ ក្នុង
# Article inserted with ID 417
# → Processing: កូរ៉េខាងជើង បញ្ជាក់ពីការដាក់ពង្រាយ ទ័ពទៅកាន់រុស្ស៊
# Article inserted with ID 418
# → Processing: តើជនបរទេស កំពុងបម្រើការងារ នៅកម្ពុជា មានសិទ្ធទទួលប
# Article inserted with ID 419
# → Processing: ការិយាល័យបោះឆ្នោតនៅទូទាំងប្រទេស បានបើកដំណើរការ
# Article inserted with ID 420
# → Processing: រកឃើញពលករ១០នាក់ មានអាការៈលើសកំដៅ ខណៈពលករជាង៥០០នាក់
# Article inserted with ID 421
# → Processing: សម្ដេច ស ខេង ដាក់ឲ្យប្រើប្រាស់និមិត្តសញ្ញា និងត្រា
# Article inserted with ID 422
# → Processing: ជប៉ុន និងអឺរ៉ុប ព្រមព្រៀងគ្នាជំរុញ កិច្ចសហប្រតិបត្
# Article inserted with ID 423
# → Processing: តើថៅកែរបស់អ្នក បានចុះឈ្មោះអ្នក ចូលជាសមាជិក ប ស ស ហ
# Article inserted with ID 424
# → Processing: សម្តេចតេជោ បញ្ជាឲ្យយកឈើខុសច្បាប់ ចាប់បាន មកធ្វើក្ត
# Article inserted with ID 425
# → Processing: ទូលព្រះបង្គំជាខ្ញុំ កៅ ថាច សូមថ្វាយព្រះពរសម្តេចព្រ
# Article inserted with ID 426
# → Processing: ថៃ នឹងទទួលបានវ៉ាក់សាំង បន្ថែមប្រមាណជា៦០លានដូស ថែមទ
# Article inserted with ID 427
# → Processing: សម្ដេច ស ខេង ៖ ក្រុមឧក្រិដ្ឋជន យកឱកាសកូវីដ ១៩ ដើម្
# Article inserted with ID 428
# → Processing: ទឹកនៅខេត្តព្រះវិហារ លើសកម្រិតប្រកាស អាសន្នហើយ
# Article inserted with ID 429
# → Processing: គណៈរដ្ឋមន្ត្រី អនុម័តទាំងស្រុងលើ សេចក្ដីព្រាងច្បាប
# Article inserted with ID 430
# → Processing: អ៊ីរ៉ង់ កោះហៅ បេសកជន អូស្ត្រាលី ជុំវិញ ជំហរ លំអៀង
# Article inserted with ID 431
# → Processing: ឯកឧត្តម ឧត្តមសេនីយ៍ឯក ជួន ណារិន្ទ ផ្ញើសារលិខិតគោរព
# Article inserted with ID 432
# → Processing: កូវីដ៖ គ្មានឆ្លង ស្លាប់ និងជាសះស្បើយថ្មីទៀតទេ
# Article inserted with ID 433
# → Processing: ប៉ាឡេស្ទីន ថ្កោលទោសអ៊ីស្រាអែល ចំពោះការបដិសេធ មិនបន
# Article inserted with ID 434
# → Processing: បទវិភាគ៖ ហេតុអ្វីបានជាហ្វីលីពីន បង្កហេតុនៅ សមុទ្រច
# Article inserted with ID 435
# → Processing: មោទនភាព ក្រុមហ៊ុន ខ្មែរ ប៊ែវើរីជីស វិនិយោគលើស្តង់ដ
# Article inserted with ID 436
# → Processing: ឯកឧត្តម នាយឧត្តមសេនីយ៍ សៅ សុខា ផ្ញើសារលិខិតគោរពជូន
# Article inserted with ID 437
# → Processing: កម្ពុជា កូរ៉េ ចុះ ស្ដីពី ការបង្កើត ក្រុមការងាររួម
# Article inserted with ID 438
# → Processing: តៃវ៉ាន់ នឹងពិភាក្សាពីការបន្ធូរបន្ថយ ជំនួញវ៉ាក់សាំង
# Article inserted with ID 439
# → Processing: លោក ត្រាំ បញ្ជាក់ថា អាមេរិក នឹងចុះហត្ថលេខា លើកិច្ច
# Article inserted with ID 440
# → Processing: មេប៉ូលិសថៃ អះអាងថាករណីបាញ់សម្លាប់ លោកលឹម គឹមយ៉ា ជា
# Article inserted with ID 441
# → Processing: សម្ដេចតេជោ ឲ្យប្រុងប្រយ័ត្នខ្ពស់ ចំពោះសន្តិសុខជាតិ
# Article inserted with ID 442
# → Processing: ឱនភាពថវិកាប្រចាំឆ្នាំ របស់សហរដ្ឋអាមេរិកធំបំផុត ចាប
# Article inserted with ID 443
# → Processing: ៖ រដ្ឋាភិបាលយោធាមីយ៉ាន់ម៉ា ត្រូវបានចោទប្រកាន់ថា បា
# Article inserted with ID 444
# → Processing: រុស្សី ចាប់ផ្តើមសមយុទ្ធយោធា ទ្រង់ទ្រាយធំនៅក្នុងតំប
# Article inserted with ID 445
# → Processing: បទវិភាគ៖ ពហុកីទ្បដ្ឋានថ្មី សម័យតេជោសន្តិភាព ជាមរតក
# Article inserted with ID 446
# → Processing: កូវីដ៖ ឆ្លងថ្មី៣៦៦នាក់ ជា៥០៧នាក់ និងស្លាប់៥នាក់
# Article inserted with ID 447
# → Processing: ឥណ្ឌា កំពុងសម្លឹងមើលឳកាស ក្នុងការចុះកិច្ចព្រមព្រៀង
# Article inserted with ID 448
# → Processing: អាមេរិក ឆ្លើយតបខុសពីកូរ៉េខាងត្បូង ពាក់ព័ន្ធបញ្ហាធ្
# Article inserted with ID 449
# → Processing: សម្តេចតេជោ ៖ ខ្ញុំចាក់វ៉ាក់សាំង រួច២ម៉ោងហើយ អត់មាន
# Article inserted with ID 450
# → Processing: រដ្ឋាភិបាលក្រុងគៀវ៖ អ៊ុយក្រែន នឹងអាចចូលរួមអឺរ៉ុប ប
# Article inserted with ID 451
# → Processing: សម្ដេច ស ខេង បង្កើតក្រុមការងារ រដ្ឋាភិបាលឌីជីថល បច
# Article inserted with ID 452
# → Processing: ឥណ្ឌា បំបែកកំណត់ត្រាទាំងករណីឆ្លង និងស្លាប់ដោយសារជំ
# Article inserted with ID 453
# → Processing: លោក ខូយ រីដា អញ្ជើញចុះពិនិត្យ វឌ្ឍនភាពការងារសាង់សង
# Article inserted with ID 454
# → Processing: សម្ដេចតេជោ ហ៊ុន សែន ណែនាំឲ្យរៀបចំចាក់ វ៉ាក់សាំងកូវ
# Article inserted with ID 455
# → Processing: វៀតណាម ៖ រថយន្តអគ្គិសនី១គ្រឿងផ្ទុះឆេះ និងរាលដាលដល់
# Article inserted with ID 456
# → Processing: ៖ កូរ៉េខាងជើង រិះគន់សហរដ្ឋអាមេរិក ទៅលើការបញ្ជូនរថព
# Article inserted with ID 457
# → Processing: នាយករដ្ឋមន្រ្តីកម្ពុជា អបអរសាទរកីឡាការិនី កែ ឡេង ឈ
# Article inserted with ID 458
# → Processing: គេហដ្ឋានរបស់ អតីតប្រធានក្រុមប្រឹក្សាពិសេស និងជារដ្
# Article inserted with ID 459
# → Processing: ក្រុមហាម៉ាស់ បន្ដប្តេជ្ញាចិត្ត ចំពោះកិច្ចព្រមព្រៀង
# Article inserted with ID 460
# → Processing: ក្រសួងព័ត៌មាន អំពាវនាវ ដល់ប្រព័ន្ធផ្សព្វផ្សាយ ត្រូ
# Article inserted with ID 461
# → Processing: ប្រតិភូនៃគណៈកម្មការ យោធាមជ្ឈឹម កងទ័ពរំដោះប្រជាជនចិ
# Article inserted with ID 462
# → Processing: បទវិភាគ ៖ ការប្រកួតកីឡាអូឡាំពិក រដូវរងាក្រុងប៉េកាំ
# Article inserted with ID 463
# → Processing: អ៊ីរ៉ង់៖ អាមេរិក បារាំង ត្រូវតែធ្វើការ សម្រេចចុងក្
# Article inserted with ID 464
# → Processing: បទវិភាគ ៖ ការធ្វើការ ស៊ើបអង្កេតដោយសត្យានុម័ត និងយុ
# Article inserted with ID 465
# → Processing: គ្រួសារកក់ក្តៅ ចែករំលែកបទពិសោធ៍ដល់ស្ត្រី ពីវិធីសាស
# Article inserted with ID 466
# → Processing: ឥណ្ឌា ប្រកាសបិទប្រទេស ទាំងមូលរយៈពេល២១ថ្ងៃ ដើម្បីកា
# Article inserted with ID 467
# → Processing: អង់គ្លេស គំរាមចាប់ផ្តើមដំណើរការដោះស្រាយវិវាទ និងពិ
# Article inserted with ID 468
# → Processing: រដ្ឋបាល ខេត្តស្វាយរៀង ទទួលអំណោយ ពីសប្បុរសជន ចូលរួម
# Article inserted with ID 469
# → Processing: ព័ត៌មានជាតិនិងអន្តរជាតិ សំខាន់ៗប្រចាំថ្ងៃ
# Article inserted with ID 470
# → Processing: ,
# Article inserted with ID 471
# → Processing: កម្មករនិងសហជីពគាំទ្រឱ្យមាន ប ស ស ដល់បុគ្គលស្វ័យនិយ
# Article inserted with ID 472
# → Processing: ក្រសួងមហាផ្ទៃ សម្រេចទទួលស្គាល់ សមាសភាពរបស់ គណបក្សជ
# Article inserted with ID 473
# → Processing: កូរ៉េខាងជើង បាញ់ មី ស៊ី ល រយៈ ចម្ងាយ ខ្លី ៤ គ្រាប់
# Article inserted with ID 474
# → Processing: សហរដ្ឋអាមេរិក នឹងចរចារក្រោយ វាំងនន ជាមួយចិន រកដំណោ
# Article inserted with ID 475
# → Processing: កម្ពុជា សង្ឃឹមថា នឹងអាចដកខ្លួនចេញពី បញ្ជីប្រផេះឱ្យ
# Article inserted with ID 476
# → Processing: ប ស ស ជួបពិភាក្សាការងារ ជាមួយ ក្រសួងកិច្ចការនារី ល
# Article inserted with ID 477
# → Processing: ស្ពានមិត្តភាពកម្ពុជា ចិន មេគង្គក្រចេះ នឹងបើកជូនប្រ
# Article inserted with ID 478
# → Processing: រុស្ស៊ី ប្រាប់ដល់អាមេរិកថា កុំ ប្រលែងជាមួយភ្លើង ជា
# Article inserted with ID 479
# → Processing: រាជរដ្ឋាភិបាល លើកទឹកចិត្ត និងផ្តល់ ឱកាស ដល់ស្ដ្រីច
# Article inserted with ID 480
# → Processing: ផ្សារ ជីប ម៉ុង ស៊ុបភើម៉ាឃីត បានប្រមូលទិញល្ពៅរាប់តោ
# Article inserted with ID 481
# → Processing: ព័ត៌មានសំខាន់ៗប្រចាំថ្ងៃ
# Article inserted with ID 482
# → Processing: អ៊ីរ៉ង់ បញ្ជាក់ថា នឹងមិនបន្តការចរចាឡើងវិញទេ លុះត្រ
# Article inserted with ID 483
# → Processing: បានមកដល់ ទីផ្សារប្រទេស កម្ពុជា ហើយ
# Article inserted with ID 484
# → Processing: ចូលរួមអបអរ ថៃ នឹងចាប់ផ្តើមធ្វើពិសោធន៍ លើវ៉ាក់សាំងក
# Article inserted with ID 485
# → Processing: អូស្ត្រាលី នឹងផ្តល់ជំនួយអភិវឌ្ឍន៍ជាង ៨៣ លានដុល្លារ
# Article inserted with ID 486
# → Processing: ពេជ្រ សម្បត្តិ៖ដឹងតែកក្រើក និងល្អមើលហើយអ្នក កំពង់ច
# Article inserted with ID 487
# → Processing: អ៊ីស្រាអែល បញ្ជាក់ថា ខ្លួនគ្រោង នឹងជម្លៀសប្រជាជន ច
# Article inserted with ID 488
# → Processing: ទឹកជំនន់ កំពុងវាយប្រហារ ប្រទេសថៃ, អ្នក ភូមិ អយុធ្យ
# Article inserted with ID 489
# → Processing: លោក ដូណាល់ ត្រាំ គំរាមដាក់ពន្ធ ៥០ លើប្រេស៊ីល ដែលនឹ
# Article inserted with ID 490
# → Processing: រាជរដ្ឋាភិបាលកម្ពុជា កំពុងបន្តដោះស្រាយបញ្ហាជាច្រើន
# Article inserted with ID 491
# → Processing: សម្តេចតេជោ ស្នើបារាំងបន្តតាមដាន ស្ថានភាពព្រំដែនកម្
# Article inserted with ID 492
# → Processing: លោក គួច ចំរើន និងភរិយា បោះឆ្នោតរួចរាល់ នៅការិយាល័យ
# Article inserted with ID 493
# → Processing: វៀតណាម បន្ថែមមន្ទីរពេទ្យ២ទៀត ដើម្បីដាក់ព្យាបាលអ្នក
# Article inserted with ID 494
# → Processing: ការស្វែងរកប្រភពដើម នៃជំងឺកូវីដ ១៩ គួរតែផ្អែកលើវិទ្
# Article inserted with ID 495
# → Processing: អ៊ីរ៉ង់បើកការវាយប្រហារសងសឹក ដោយបាញ់មីស៊ីលផ្លោងរាប់
# Article inserted with ID 496
# → Processing: សម្តេចធិបតី អញ្ជើញសម្ពោធអគារ រដ្ឋបាលថ្មី និងសមិទ្ធ
# Article inserted with ID 497
# → Processing: វៀតណាម និងរុស្ស៊ី ប្ដេជ្ញាធ្វើឲ្យ ទំនាក់ទំនងទ្វេភា
# Article inserted with ID 498
# → Processing: រុស្ស៊ី ណែនាំពលរដ្ឋរបស់ខ្លួនកុំឱ្យ ធ្វើដំណើរទៅកាន់
# Article inserted with ID 499
# → Processing: សម្តេចតេជោ ៖ ពលរដ្ឋនៅទូទាំងប្រទេសបានសោកស្តាយចំពោះក
# Article inserted with ID 500
# → Processing: កីឡាករ បាល់បោះ សញ្ជាតិបារាំង លេងឱ្យក្លឹបនៅចិន ត្រូ
# Article inserted with ID 501
# → Processing: ខេត្តសៀមរាប រកឃើញអ្នកវិជ្ជមាន ជំងឺកូវី ១៩ ថ្មី៥នាក
# Article inserted with ID 502
# → Processing: យោធាចិន បើកសមយុទ្ធទ្រង់ទ្រាយធំ ជុំវិញកោះតៃវ៉ាន់ ដើ
# Article inserted with ID 503
# → Processing: អ៊ីស្រាអែល វាយប្រហារតាមអាកាសជាបន្តបន្ទាប់ ចូលក្នុង
# Article inserted with ID 504
# → Processing: លោក ដូណាល់ ត្រាំ នឹងសម្រេចចិត្តធ្វើសកម្មភាព ប្រឆាំ
# Article inserted with ID 505
# → Processing: ឥណ្ឌូនេស៊ី ប្រឆាំងដាច់ខាត បន្ទាប់ពី អំពាវនាវមិនឲ្យ
# Article inserted with ID 506
# → Processing: ៖ អ៊ីស្រាអ៊ែល បញ្ជាក់ថា មេបញ្ជាការជាន់ខ្ពស់ របស់ក្
# Article inserted with ID 507
# → Processing: អ៊ុយក្រែន និងមន្ត្រីការទូតជាន់ខ្ពស់ សហភាពអឺរ៉ុប ពិ
# Article inserted with ID 508
# → Processing: ទូតកម្ពុជា ប្រាប់ពីវិធានការបន្ថែម របស់រដ្ឋាភិបាលស្
# Article inserted with ID 509
# → Processing: បទវិភាគ៖ សមភាព ពូជសាសន៍ គឺជា រឿង ដែល មិនអាច សម្រេច
# Article inserted with ID 510
# → Processing: សប្បុរសជនបន្ត ផ្ដល់អំណោយ ជូនរដ្ឋបាល ខេត្តកំពង់ចាម
# Article inserted with ID 511
# → Processing: សភាជាន់ទាប របស់ប្រទេសថៃ អនុម័តច្បាប់ថវិកាជាង ១០០ពា
# Article inserted with ID 512
# → Processing: លោក នឹងមិនបន្តការពិភាក្សា អំពីបញ្ហាតម្លើងពន្ធទៀតឡើ
# Article inserted with ID 513
# → Processing: ចិន តែងតាំង អ្នក ចរចា ពាណិជ្ជកម្ម អន្តរជាតិ កំពូល
# Article inserted with ID 514
# → Processing: ៥ខែ កម្ពុជាទទួលផល ស្រូវរដូវប្រាំង ២,៩៣លានតោន និងនា
# Article inserted with ID 515
# → Processing: កម្ពុជា អូស្រ្តាលី ប្រកាសផ្សព្វផ្សាយ នឹងដាក់ឲ្យអនុ
# Article inserted with ID 516
# → Processing: កំណែទម្រង់ និងការបើកទូលាយ គឺជាមាគ៌ាឈ្នះ ឈ្នះ សម្រា
# Article inserted with ID 517
# → Processing: ប៉ូឡូញ ស្នើសុំអឺរ៉ុប ដើម្បីជួយបង្កើនសមត្ថភាពយោធា ត
# Article inserted with ID 518
# → Processing: កម្ពុជា មានអ្នកឆ្លងកូវីដថ្មី ចំនួន៤៨០នាក់ ជាថ្មី ៣
# ...
# Article inserted with ID 7686
# → Processing: ឧបនាយករដ្ឋមន្ត្រី ស៊ុន ចាន់ថុល អញ្ជើញវិនិយោគិនកាណា
# Article inserted with ID 7687
# → Processing: ព័ត៌មានអន្តរជាតិសំខាន់ៗប្រចាំថ្ងៃ
# Article inserted with ID 7688
# → Processing: បទវិភាគ ៖ ចិនកំពុងចែករំលែក ឱកាសជាមួយពិភពលោក ដោយកម្
# Article inserted with ID 7689
# → Processing: អ្នកវិភាគនៅកម្ពុជា ៖ ផ្លាស់ចេញពីរដ្ឋមន្រ្តីការបរទេ
# Article inserted with ID 7690
# → Processing: កម្ពុជា បញ្ជាក់ជំហរ មិនបង្កើតទំនាក់ទំនងផ្លូវការ ជា
# Article inserted with ID 7691
# → Processing: ប្រធានាធិបតីអ៊ីរ៉ង់ ៖ កិច្ចព្រមព្រៀងអាចធ្វើទៅបាន ប
# Article inserted with ID 7692
# → Processing: វៀតណាម មានករណីឆ្លងថ្មីនៃជំងឺកូវីដ ១៩ ចំនួនជាង ២០០ន
# Article inserted with ID 7693
# → Processing: កម្ពុជា នាំចេញគ្រាប់ស្វាយចន្ទីឆៅ ទៅទីផ្សារអន្តជាតិ
# Article inserted with ID 7694
# → Processing: លោក ដូណាល់ ត្រាំ ព្រមានទៅលោក ណេតាន់យ៉ាហ៊ូ ចំពោះការ
# Article inserted with ID 7695
# → Processing: ព័ត៌មានជាតិនិងអន្តរជាតិ សំខាន់ៗប្រចាំថ្ងៃ
# Article inserted with ID 7696
# → Processing: ឯកឧត្តម លឹម គានហោ ក្រាបបង្គំទូលថ្វាយ សព្ទសាធុការពរ
# Article inserted with ID 7697
# → Processing: កូរ៉េខាងត្បូង ប្ដេជ្ញាបញ្ចប់កិច្ចចរចា ចែករំលែកចំណា
# Article inserted with ID 7698
# → Processing: ៖ ថា ខ្លួនត្រូវការថវិកា៣៧៥ លានដុល្លារ សម្រាប់ជួយដល
# Article inserted with ID 7699
# → Processing: ព័ត៌មានជាតិសំខាន់ៗប្រចាំថ្ងៃ
# Article inserted with ID 7700
# → Processing: ក្រុមហ៊ុន ស្មាត ដាក់ឈ្មោះ ប្រព័ន្ធរបស់ខ្លួន លើទូរស
# Article inserted with ID 7701
# → Processing: ពលរដ្ឋមីយ៉ាន់ម៉ា បន្ដធ្វើបាតុកម្មក្នុងទ្រង់ទ្រាយកា
# Article inserted with ID 7702
# → Processing: ក្នុងឆ្នាំ២០២២ សមាជិក ប ស ស ប្រមាណជាង ១ ៧ម៉ឺននាក់
# Article inserted with ID 7703
# → Processing: សម្ដេចតេជោ ឲ្យខិតខំបន្ថែមទៀត កាត់បន្ថយអត្រា ឈឺ ស្ល
# Article inserted with ID 7704
# → Processing: ឯកឧត្តម ឧត្តមសេនីយ៍ឯក ម៉ឹង ពន្លក ផ្ញើសារលិខិតគោរពជ
# Article inserted with ID 7705
# → Processing: កូរ៉េខាងជើង គំរាមបាញ់ទម្លាក់យន្តហោះស៊ើប ការណ៍អាមេរ
# Article inserted with ID 7706
# → Processing: ព្រឹត្តិការណ៍កីឡាស៊ីហ្គេម ៖ កេរិ៍ឈ្មោះកម្ពុជា នឹងត
# Article inserted with ID 7707
# → Processing: សម្ដេច ព្រះធម្មលិខិត លាស់ ឡាយ សុគតដោយព្រះជរាពាធ ក្
# Article inserted with ID 7708
# → Processing: ព្រះរាជអាជ្ញារងនៃអយ្យការអមសាលាដំបូងខេត្តមណ្ឌលគិរី
# Article inserted with ID 7709
# → Processing: អភិបាលខេត្តកំពង់ចាម ជំរុញឲ្យគណៈកម្មការ អង្គភាពមន្ទ
# Article inserted with ID 7710
# → Processing: ថ្ងៃនេះថយបន្តិច ឥណ្ឌា មានអ្នកឆ្លងជំងឺកូវីដ ១៩ សរុប
# Article inserted with ID 7711
# → Processing: រយៈពេលត្រឹម ១សប្ដាហ៍ អង់គ្លេស រកឃើញករណី ឆ្លងជំងឺកូ
# Article inserted with ID 7712
# → Processing: អង់គ្លេស ៖ វិមានក្រឹមឡាំង ទទួលស្គាល់ការបរាជ័យ របស់
# Article inserted with ID 7713
# → Processing: ខ្លាចាស់ ធន់ អៀងឡេង ក្លាយជាម្ចាស់ជើងឯក គុនខ្មែរប៉ុ
# Article inserted with ID 7714
# → Processing: នាយករដ្ឋមន្ត្រីជប៉ុន និងប្រធានាធិបតីថ្មីអាមេរិក នឹ
# Article inserted with ID 7715
# → Processing: អង់គ្លេស ទទួលបានភ្លៀង ខៀវឲ្យចាប់ផ្តើម កិច្ចពិភាក្ស
# Article inserted with ID 7716
# → Processing: នាយករដ្ឋមន្រ្តីថ្វាយព្រះពរ ព្រះមហាក្សត្រ ក្នុងឱកាស
# Article inserted with ID 7717
# → Processing: លោក ឃួង ស្រេង៖ ក្រោមម្លប់សន្តិភាព ប្រជាធិបតេយ្យនៅក
# Article inserted with ID 7718
# → Processing: ឧកញ៉ា ទៀ វិចិត្រ ឧបត្ថម្ភថវិកា ៥ម៉ឺនដុល្លារ តាមរយៈ
# Article inserted with ID 7719
# → Processing: កងទ័ពស៊ូដង់ អះអាងថា យុទ្ធជនប៉ារ៉ា ១៥០នាក់ ត្រូវបាន
# Article inserted with ID 7720
# → Processing: លោក និយាយថា មីស៊ីលសម្រាប់យន្តហោះ របស់ជប៉ុន នឹងមកដល
# Article inserted with ID 7721
# → Processing: ទីក្រុងមូស្គូ និងទីក្រុងគៀវព្រមព្រៀងគ្នា ក្នុងការដ
# Article inserted with ID 7722
# → Processing: ខ្មែរខ្លាំងមិនអាស្រ័យ គឺអាស្រ័យលើក្រុមហ៊ុនខ្មែរខ្ល
# Article inserted with ID 7723
# → Processing: ប្រធានាធិបតីអ៊ីស្រាអែល ព្រមានធ្វើសង្គ្រាម ប្រឆាំងក
# Article inserted with ID 7724
# → Processing: កម្ពុជា ជឿជាក់ថា ឥណ្ឌា អាចដើរតួនាទីសមស្រប ក្នុងការ
# Article inserted with ID 7725
# → Processing: បទវិភាគ ៖ ការធ្វើសង្គ្រាម ពន្ធគយ មិនអំណោយផល ដល់ប្រ
# Article inserted with ID 7726
# → Processing: តួឯកក្នុងរឿង ទទួលមរណភាព បន្ទាប់ពីតស៊ូជាមួយ ជំងឺមហា
# Article inserted with ID 7727
# → Processing: វៀតណាម បង្ក្រាបអំពើពុករលួយ៖ អតីតជំនួយការរបស់អនុរដ្
# Article inserted with ID 7728
# → Processing: អ៊ីរ៉ង់ កោះហៅបេសកជនពិសេសប៉ូឡូញ ជុំវិញការអធិប្បាយរប
# Article inserted with ID 7729
# → Processing: ព័ត៌មានជាតិ និង អន្តរជាតិសំខាន់ៗប្រចាំថ្ងៃ
# Article inserted with ID 7730
# → Processing: ប្រធានាធិបតីកូរ៉េខាងជើង អាចនឹងធ្វើដំណើរ តាមរថភ្លើង
# Article inserted with ID 7731
# → Processing: សម្ដេចតេជោ នឹងសរសេរសៀវភៅ រឿងរ៉ាវកើតឡើង តាំងពីឆ្នាំ
# Article inserted with ID 7732
# → Processing: មិត្តហ្វូន ដាំដើមឈើ ១០០០ដើម នៅខេត្តសៀមរាប រួមដៃគ្ន
# Article inserted with ID 7733
# → Processing: ស្រាបៀរអាន់ឆ័រ ចាប់រង្វាន់ផ្តាច់ព្រ័ត្រ សម្រាប់កម្
# Article inserted with ID 7734
# → Processing: ថៃ៖ អ្នកទេសចរអឺរ៉ុប ១៧នាក់របួស ក្នុងគ្រោះថ្នាក់ចរា
# Article inserted with ID 7735
# → Processing: រដ្ឋមន្ដ្រីសុខាភិបាល ណែនាំប្រុងប្រយ័ត្ន ចំពោះអាកាស
# Article inserted with ID 7736
# → Processing: សម្តេចធិបតី៖ ក្រោមម្លប់ដ៏សែនត្រជាក់នៃសន្តិភាព ស្ទើ
# Article inserted with ID 7737
# → Processing: សម្ដេចតេជោ ស្នើរដ្ឋមន្ដ្រីយុត្តិធម៌ និងមហាផ្ទៃពិភា
# Article inserted with ID 7738
# → Processing: ថៃ៖ ការរុះរើក្នុងជួរយោធា នឹងត្រូវធ្វើរួចរាល់នៅក្នុ
# Article inserted with ID 7739
# → Processing: កូវីដ៖ ឆ្លងថ្មី១៥នាក់ ជា៣៣នាក់ និងស្លាប់គ្មាន
# Article inserted with ID 7740
# → Processing: អាមេរិក ប្រកាសតម្លើងពន្ធលើការនាំចូលនាំមាស, ស្វីសគឺ
# Article inserted with ID 7741
# → Processing: គុយបា ទទួលស្គាល់ការ រីកចម្រើនលើគ្រប់វិស័យ របស់កម្ព
# Article inserted with ID 7742
# → Processing: មេដឹកនាំអ៊ុយក្រែន ប្រកាសត្រៀមខ្លួន ជួបសន្ទនា ជាមួយ
# Article inserted with ID 7743
# → Processing: គន្លឹះងាយៗ ធ្វើឲ្យថ្លើមល្អ មិនក្រិនខូច
# Article inserted with ID 7744
# → Processing: ព័ត៌មានសម្ងាត់អំពី ការវាយប្រហាររបស់សហរដ្ឋអាមេរិក ល
# Article inserted with ID 7745
# → Processing: សម្តេចធិបតី ហ៊ុន ម៉ាណែត អញ្ជើញបើកវេទិកាធុរកិច្ច កម
# Article inserted with ID 7746
# → Processing: គ ជ អ ប និងអង្គការទស្សនៈពិភពលោក ដាក់ឲ្យអនុវត្តគម្រ
# Article inserted with ID 7747
# → Processing: ប្រធានរដ្ឋសភាកម្ពុជា ចូលក្រាបបង្គំ គាល់ព្រះមហាក្សត
# Article inserted with ID 7748
# → Processing: អាមេរិក ស្វះស្វែងបន្តពង្រឹង កិច្ចព្រមព្រៀងនុយក្លេអ
# Article inserted with ID 7749
# → Processing: ហូឡង់និងអង់គ្លេស ចាប់ដៃគ្នា ទៅវគ្គបន្តក្រោយឈ្នះ តួ
# Article inserted with ID 7750
# → Processing: សម្ដេច ស ខេង បញ្ជាអាជ្ញាធរ បន្តអនុវត្តន៍ជាប្រព័ន្ធ
# Article inserted with ID 7751
# → Processing: សម្តេចតេជោ ដាក់បញ្ជាតាមរក ពលករខ្មែរមកពីថៃ ដើម្បីពិ
# Article inserted with ID 7752
# → Processing: គ្រោះធម្មជាតិ នៅវៀតណាម មនុស្សស្លាប់ និងបាត់ខ្លួនកើ
# Article inserted with ID 7753
# → Processing: មន្ដ្រីរដ្ឋាភិបាល ច្រានចោលសារសំឡេងថា រាជរដ្ឋាភិបាល
# Article inserted with ID 7754
# → Processing: អាស៊ាន ចិន ជប៉ុននិងកូរ៉េខាងត្បូង ប្តេជ្ញាបង្កើនចំណ
# Article inserted with ID 7755
# → Processing: រុស្ស៊ី អរគុណអាមេរិក ដែលបានជួយអំឡុងពេល សង្គ្រាមលោក
# Article inserted with ID 7756
# → Processing: តម្លៃប្រេងកើនឡើង ដោយសារសុទិដ្ឋិនិយម នៃរដ្ឋាភិបាលអា
# Article inserted with ID 7757
# → Processing: អង់គ្លេស កំពុងអំពាវនាវឲ្យអ៊ុយក្រែន ទទួលយកការចរចា ដ
# Article inserted with ID 7758
# → Processing: កម្ពុជា ទន្ទឹមរង់ចាំថៃដោះលែង វីរៈកងទ័ពទាំង១៨នាក់ ឱ
# Article inserted with ID 7759
# → Processing: ចិន ចោទសហភាពអឺរ៉ុប និងសម្ព័ន្ធមិត្ត ថា បានអនុវត្តស
# Article inserted with ID 7760
# → Processing: ពលរដ្ឋអ៊ុយក្រែន ក្នុងប្រទេសអង់គ្លេស អាចចុះឈ្មោះចូល
# Article inserted with ID 7761
# → Processing: រុស្ស៊ី សម្ដែងការព្រួយបារម្ភ ចំពោះផែនការដាក់ពង្រាយ
# Article inserted with ID 7762
# → Processing: លោក អ៊ូ តារា៖ អ្នកលេងគុន ជាព្រឹត្តិការណ៍មួយធ្វើឡើង
# Article inserted with ID 7763
# → Processing: លោក ឃុន ពៅ៖ ទោះខ្ញុំមានពិការភាព តែមិនមែនជាឧបសគ្គសម
# Article inserted with ID 7764
# → Processing: បទវិភាគ៖ ការអភិរក្សអេកូបរិស្ថាន នៃទន្លេលឿង បង្ហាញឱ
# Article inserted with ID 7765
# → Processing: លោក ៖ អ៊ីស្រាអែល នឹងលុកលុយ ទោះមាន ឬគ្មានកិច្ចព្រមព
# Article inserted with ID 7766
# → Processing: ចែកគ្នាដឹង ប្រេងដូងធម្មជាតិ បំបាត់ស្នាមសង្វារ ក្រោ
# Article inserted with ID 7767
# → Processing: អាមេរិក ជំរុញប៉ារ៉ាហ្គាយ ឲ្យធ្វើការជាមួយតៃវ៉ាន់ ស្
# Article inserted with ID 7768
# → Processing: លោករដ្ឋមន្ត្រី ក្រសួងធនធានទឹក ចុះពិនិត្យការដ្ឋាន ស
# Article inserted with ID 7769
# → Processing: សប្តាហ៍ខាងមុខនេះ កម្ពុជានឹងរងឥទ្ធិពលខ្យល់មូសុង រដូ
# Article inserted with ID 7770
# → Processing: ទូតឲ្យពលរដ្ឋខ្មែរ នៅវៀតណាម ថែទាំសុខភាព ខណៈអាកាសធាត
# Article inserted with ID 7771
# → Processing: សម្តេចតេជោ នឹងចូលរួមកិច្ចប្រជុំអាស៊ាន នៅបាងកក ពីថ្
# Article inserted with ID 7772
# → Processing: សម្តេចតេជោ អបអរសាទរ កីឡាប៉េតង់កម្ពុជា ឈ្នះមេដាយមាស
# Article inserted with ID 7773
# → Processing: វៀតណាម ព្យាយាម ធ្វើពិពិធកម្មប្រភព វ៉ាក់សាំងកូវីដ១៩
# Article inserted with ID 7774
# → Processing: ព្រឹត្តិការណ៍សហគមន៍ ២០ កុម្ភៈ សម្ដេចតេជោ ហ៊ុន សែន
# Article inserted with ID 7775
# → Processing: បណ្តាប្រទេស ចេញសេចក្តីអំពាវនាវឲ្យចិន បញ្ឈប់ការជិះជ
# Article inserted with ID 7776
# → Processing: ព័ត៌មានជាតិ និង អន្តរជាតិសំខាន់ៗប្រចាំថ្ងៃ
# Article inserted with ID 7777
# → Processing: ប្រធានាធិបតីចិនថា ក្រុមសេដ្ឋកិច្ច និងពាណិជ្ជកម្ម រ
# Article inserted with ID 7778
# → Processing: មន្ត្រីជំនាញ ប ស ស ចូលរួមសិក្ខាសាលា ពិគ្រោះយោបល់ ន
# Article inserted with ID 7779
# → Processing: ក្រសួងមហាផ្ទៃ ចាត់តាំងនគរបាល ១២រូប ចូលរួមអនុវត្តផែ
# Article inserted with ID 7780
# → Processing: របាយការណ៍៖ អតីតអភិបាលខេត្តកំពង់ឆ្នាំងមួយរូប បានកាប
# Article inserted with ID 7781
# → Processing: សម្តេចតេជោ បន្តលើកទឹកចិត្តឲ្យ ធ្វើតេស្តរហ័សរកកូវីដ
# Article inserted with ID 7782
# → Processing: មហាអំណាចអាមេរិក វាយ តម្លៃ ខ្ពស់ ចំពោះជំហរកម្ពុជា ល
# Article inserted with ID 7783
# → Processing: ព័ត៌មានអន្តរជាតិសំខាន់ៗប្រចាថ្ងៃ
# Article inserted with ID 7784
# → Processing: នាង សមាជិកក្រុមតារាចម្រៀងកូរ៉េ រងការរិះគន់ពីអ្នកគា
# Article inserted with ID 7785
# → Processing: អត្ថប្រយោជន៍ នៃការទំពារស្ករកៅស៊ូ ក្រោយពេលញាំអាហាររ
# Article inserted with ID 7786
# → Processing: ហ៊ឹកហ៊ាក់ណាស់ឆ្នាំនេះ អ្នកចុះឈ្មោះ រត់ម៉ារ៉ាតុង ឧប
# Article inserted with ID 7787
# → Processing: ពីងពាងជាសត្វល្អិត មែនឬមិនមែន
# Article inserted with ID 7788
# → Processing:
# Article inserted with ID 7789
# → Processing: សហរដ្ឋអាមេរិក និងអ៊ីស្រាអែល នឹងពិភាក្សាគ្នាពីសមយុទ
# Article inserted with ID 7790
# → Processing: សម្ដេច ស ខេង ដឹកនាំកិច្ចប្រជុំឆ្លងសេចក្ដីព្រាងអនុក
# Article inserted with ID 7791
# → Processing: បទវិភាគ ៖ ការប្រកួតកីឡាអូឡាំពិក រដូវរងាក្រុងប៉េកាំ
# Article inserted with ID 7792
# → Processing: សម្តេចតេជោ ហ៊ុន សែន អញ្ជើញបើកការប្រកួត វាយកូនគោល ព
# Article inserted with ID 7793
# → Processing: ឯកឧត្តម ឧត្តមសេនីយ៍ត្រី ហ៊ុល វណ្ឌី ផ្ញើសារអបអរសាទរ
# Article inserted with ID 7794
# → Processing: អ្នកវិភាគ៖ លោកស្រី អាចនឹង ដោះលែងក្នុងពីរបីថ្ងៃខាងម
# Article inserted with ID 7795
# → Processing: អ្នកជំងឺកូវីដ១៩ នៅថៃ ៣៨នាក់ ស្លាប់ នៅថ្ងៃអង្គារនេះ
# Article inserted with ID 7796
# → Processing: សមាជិក ៖ ប្រជាជាតិត្រូវតែដាក់បម្រាម ក្នុងការផ្តល់ជ
# Article inserted with ID 7797
# → Processing: អាល្លឺម៉ង់ បានបង្ហាញការព្យាយាម ដើម្បីសម្រេចតាមគោលដ
# Article inserted with ID 7798
# → Processing: ក្រុមហ៊ុនផលិត រថយន្តចំនួន៥ នៅកូរ៉េខាងត្បូង នឹងចាប់
# Article inserted with ID 7799
# → Processing: សម្តេចតេជោ៖ កម្ពុជាកំពុងជួប សង្គ្រាម ប្រឆាំងជំងឺកូ
# Article inserted with ID 7800
# → Processing: កូវីដ ៖ ឆ្លងថ្មី៤៧៩នាក់ ជា៥០៣នាក់ និងស្លាប់ម្នាក់
# Article inserted with ID 7801
# → Processing: ៖ មេដឹកនាំកូរ៉េខាងជើង ដាក់បញ្ជាឲ្យអង្គភាពធំៗ របស់ខ
# Article inserted with ID 7802
# → Processing: សម្ដេច ស ខេង៖ បេីសិនស្ថានភាព កាន់តែរីកចំនួន អ្នកផ្
# Article inserted with ID 7803
# → Processing: ៖ ពលរដ្ឋប៉ាឡេស្ទីន នៅតែបន្តតវ៉ាប្រឆាំងអ៊ីស្រាអែល ន
# Article inserted with ID 7804
# → Processing: ក្រុមហ៊ុន ដាក់ឈ្មោះអ៊ីស្រាអែលថា សាធារណរដ្ឋចេក និងប
# Article inserted with ID 7805
# → Processing: មូលដ្ឋានទ័ពអាកាសអឺរ៉ុប ដ៏ធំបំផុត របស់អង្គការណាតូ ត
# Article inserted with ID 7806
# → Processing: ព័ត៌មានអន្តរជាតិសំខាន់ៗប្រចាំសប្ដាហ៍
# Article inserted with ID 7807
# → Processing: គណបក្សប្រជាជនកម្ពុជា ចេញសេចក្ដីថ្លែងការណ៍បញ្ជាក់អំ
# Article inserted with ID 7808
# → Processing: ការពង្រឹងឧត្តមភាពថ្មី រវាង អាមេរិក រុស្សីនិងចិន ឆ្
# Article inserted with ID 7809
# → Processing: កំណើន របស់ចិន នៅត្រីមាសទី២ ធ្លាក់ចុះដល់ ៥ ២ ចំពេលម
# Article inserted with ID 7810
# → Processing: សម្តេច សាយ ឈុំ ស្នើឆែកជំរុញការ ផ្លាស់ប្ដូរពាណិជ្ជក
# Article inserted with ID 7811
# → Processing: ព័ត៌មានជាតិនិងអន្តរជាតិ សំខាន់ៗប្រចាំថ្ងៃ
# Article inserted with ID 7812
# → Processing: គុយបា គាំទ្រកម្ពុជាពេញ ទំហឹងចំពោះចំណាត់ការ លើក្រុម
# Article inserted with ID 7813
# → Processing: អ៊ីរ៉ង់ជោគជ័យ ក្នុងការបញ្ជូនសំភារៈ ចាំបាច់ទំហំជាង៣
# Article inserted with ID 7814
# → Processing: ប្រមូលសិនពិសេស ខប់ខប់
# Article inserted with ID 7815
# → Processing: សហការ ជាមួយក្រសួងសុខាភិបាល និងអាជ្ញាធរចុះយុទ្ធនាកា
# Article inserted with ID 7816
# → Processing: កម្មវិធីរាត្រីសមោសរ អបអរសាទរអ្នកច្នៃម៉ូដ និងអ្នកបង
# Article inserted with ID 7817
# → Processing: ចំនួនអ្នកស្លាប់ ដោយសារជំងឺកូវីដ ១៩ នៅអ៊ីតាលី កើនឡើ
# Article inserted with ID 7818
# → Processing: អឺរ៉ុប កំពុងពិចារណាលើពន្ធសងសឹក ២៥ លើទំនិញមួយចំនួនរ
# Article inserted with ID 7819
# → Processing: សម្ដេចតេជោ ហ៊ុន សែន ៖ ការកែសម្រួលកម្លាំងកងទ័ពនៅតំប
# Article inserted with ID 7820
# → Processing: កូរ៉េខាងជើង ចាត់ទុកទណ្ឌកម្មថា ជាឧបសគ្គក្នុងការសម្រ
# Article inserted with ID 7821
# → Processing: ដាក់ ចេញ នូវកម្មវិធី ថ្មី ដើម្បី សម្រួល ដល់ ការ ប្
# Article inserted with ID 7822
# → Processing: សម្ដេចធិបតី អបអរសាទរថ្នាលផ្ទៀងផ្ទាត់ឯកសាររបស់កម្ពុ
# Article inserted with ID 7823
# → Processing: អាមេរិក អំពាវនាវឲ្យជប៉ុន ពន្យារពេលព្រឹត្ដិការណ៍កីឡ
# Article inserted with ID 7824
# → Processing: អាជ្ញាធរ ខេត្តកំពង់ចាម ចុះពិនិត្យកែលម្អ សណ្ឋាគារមេ
# Article inserted with ID 7825
# → Processing: ផ្ទះ មានចំណូលស្រាប់ ទំហំជាង ដាក់លក់ ទីតាំងស្ថិតនៅ
# Article inserted with ID 7826
# → Processing: ពលរដ្ឋរងគ្រោះ១១៦០ គ្រួសារ រងគ្រោះដោយជំនន់ទឹកភ្លៀង
# Article inserted with ID 7827
# → Processing: បទវិភាគ៖ ប្រទេសចិន ក្លាយជា កម្លាំង សំខាន់ ក្នុងការ
# Article inserted with ID 7828
# → Processing: សម្ដេចតេជោ ហ៊ុន សែន ប្ដេជ្ញាជំរុញការវិនិយោគថ្មីៗបន
# Article inserted with ID 7829
# → Processing: អភិបាល ខេត្តកំពង់ចាម ចេញបញ្ជាដាច់ខាត មិនឲ្យមានការច
# Article inserted with ID 7830
# → Processing: ៖ ទោះបីជាពិភពលោក មានករណី កូវីដ១៩ថ្មី ថយចុះក្នុងរយៈ
# Article inserted with ID 7831
# → Processing: សម្តេចតេជោ អញ្ជើញជាអធិបតីភាព ពិធីចុះហត្ថលេខាផ្ដល់
# Article inserted with ID 7832
# → Processing: វៀតណាម តែងតាំងប្រធានសភាថ្មី បន្ទាប់ប្រធានសភាចាស់ ល
# Article inserted with ID 7833
# → Processing: រដ្ឋាភិបាល អង់គ្លេស បង្កើនសម្ពាធ លើរដ្ឋសភាជុំវិញ ក
# Article inserted with ID 7834
# → Processing: ជប៉ុន ប្រារព្ធខួបលើកទី ៨០ នៃការវាយឆ្មក់តាមអាកាសរបស
# Article inserted with ID 7835
# → Processing: អ៊ីស្រាអែល សម្រេចបង្កើន យុទ្ធនាការយោធា ប្រឆាំងនឹងក
# Article inserted with ID 7836
# → Processing: លោក ប្រដូចការវាយប្រហារ លើប្រទេសអ៊ីរ៉ង ដូចទៅនឹងការវ
# Article inserted with ID 7837
# → Processing: អ៊ុយក្រែន ជំរុញសម្ពន្ធមិត្តលោកខាងលិច ឲ្យដាក់ទណ្ឌកម
# Article inserted with ID 7838
# → Processing: គម្រោងភូមិឋាន ធម្មជាតិក្រុងភ្នំ នឹងជួយលើកកម្ពស់ សម
# Article inserted with ID 7839
# → Processing: រដ្ឋាភិបាល ទីក្រុងប៊ែកឡាំងថា អាល្លឺម៉ង់ មិនមែនជាសម
# Article inserted with ID 7840
# → Processing: សម្តេចតេជោ ហៅស្រ្តីម្នាក់នៅក្រៅប្រទេស ដែលចង់កំចាត់
# Article inserted with ID 7841
# → Processing: ចិន ចង់ឲ្យអាមេរិក អញ្ជើញអង្គការ សុខភាពពិភពលោក ដើម្
# Article inserted with ID 7842
# → Processing: វៀតណាម រកឃើញថា មានអ្នកឆ្លងជំងឺកញ្ជ្រិល រហូតដល់៤២ករ
# Article inserted with ID 7843
# → Processing: កាលពីថ្ងៃអាទិត្យ វៀតណាម រកឃើញអ្នកឆ្លងកូវីដ១៩ចំនួន
# Article inserted with ID 7844
# → Processing: សមាជិកសហភាពអឺរ៉ុប យល់ព្រមលើកការគ្រប់គ្រង ដែនអាកាស
# Article inserted with ID 7845
# → Processing: កម្ពុជា គាំទ្រប្រកាសរួមស្តីពី កិច្ចសហការផ្តល់ប្រយោ
# Article inserted with ID 7846
# → Processing: ព័ត៌មានអន្តរជាតិសំខាន់ៗប្រចាំថ្ងៃ
# Article inserted with ID 7847
# → Processing: លោក ម៉ឹង យូឡេង គោរពជូនពរ សម្តេចតេជោ និងសម្តេចកិត្ត
# Article inserted with ID 7848
# → Processing: តើអ្នកធ្លាប់បាន ទទួលការបដិសេធ ដែរឬទេ
# Article inserted with ID 7849
# → Processing: ប្រទេសចិន ផ្តល់ជំនួយជាសកល ក្នុងការប្រយុទ្ធ ប្រឆាំង
# Article inserted with ID 7850
# → Processing: សម្តេចធិបតី បញ្ជាក់ទៅភាគីថៃថា គ្មានឡើយការជួបចរចាទ្
# Article inserted with ID 7851
# → Processing: រុស្ស៊ី ប្រកាសត្រៀមខ្លួន គាំទ្រការអភិវឌ្ឍនុយក្លេអ៊
# Article inserted with ID 7852
# → Processing: បទវិភាគ ៖ របាយការណ៍ចំនួនពីរច្បាប់ លាតត្រដាងថា តើអ្
# Article inserted with ID 7853
# → Processing: ១ ថ្ងៃសោះ ខ្មែរ ប៊ែវើរីជីស ចែករង្វាន់ម៉ូតូ ៦ រង្វា
# Article inserted with ID 7854
# → Processing: ឥណ្ឌា ចាប់ផ្តើមធ្វើការ បណ្តេញចេញទ្រង់ទ្រាយធំ រាល់ជ
# Article inserted with ID 7855
# → Processing: ព្យុះ នឹងវាយប្រហារប្រទេសថៃ ដែលនឹងធ្វើឱ្យមានភ្លៀងធ្
# Article inserted with ID 7856
# ETL Completed Successfully!
