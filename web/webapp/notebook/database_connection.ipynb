# %%
import psycopg2

# Most basic localhost connection (uses default values)
conn = psycopg2.connect(
    host="localhost",
    database="mates",  # default database
    user="postgres",      # default user
    password="1"
)

# Alternative connection string
conn = psycopg2.connect("postgresql://postgres:1@localhost:5432/mates")
